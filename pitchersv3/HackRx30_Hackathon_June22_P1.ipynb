# %% [markdown]
# #Recommendation of Product on the basis of Feature Extracted from the product details and the co-purchases made

# %% [markdown]
# ##1. Data Extraction from unstructured text dataset into structured dataframe

# %%
"""from google.colab import drive
drive.mount('/content/drive')"""
# Out:
# "from google.colab import drive\ndrive.mount('/content/drive')"

# %%
import pandas as pd
import re
from pprint import pprint
import networkx as nx
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics.pairwise import cosine_similarity

# %%
# !pip install gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (4.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.64.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2022.6.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !gdown --id 1-MyYRp_5NnmU1JWvl1jV6Dhe3o2HAjdc
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1-MyYRp_5NnmU1JWvl1jV6Dhe3o2HAjdc
# To: /content/amazon-meta.txt
# 100% 978M/978M [00:07<00:00, 123MB/s]

# %%
# !gdown --id 1XwBFgm_vdUTCe6LUkqSSNJanVOpx7OGP
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1XwBFgm_vdUTCe6LUkqSSNJanVOpx7OGP
# To: /content/amazon0601.txt
# 100% 47.9M/47.9M [00:00<00:00, 215MB/s]

# %% [markdown]
# ### 1.1 Creating dataframe from meta dataset of products by iterating through text-file

# %%
filepath = '/content/amazon-meta.txt'
text = open(filepath, 'r', encoding = 'utf-8')

# %%
Ids = []
ASINs = []
titles =[]
salesranks = []
similars = []
num_categories = []
groups = []
categories = []
reviews = []
reviewinfo = []
lc = 0
for line in text:
    lastcat = False
    lastrev = False
    categoies =[]
    lineelements = line.split(':')
    lineelements = [x.strip() for x in lineelements]
    if 'Id' == lineelements[0]:
        Ids.append(lineelements[1])
    elif 'ASIN' == lineelements[0]:
        ASINs.append(lineelements[1])
    elif 'discontinued product' in lineelements:
        Ids.pop(-1)
        ASINs.pop(-1)
    elif 'title' == lineelements[0]:
        titles.append(''.join(lineelements[1]))
    elif 'group' == lineelements[0]:
        groups.append(lineelements[1])
    elif 'salesrank' == lineelements[0]:
        salesranks.append(lineelements[1])
    elif 'similar' == lineelements[0]:
        lineelements.pop(0)
        element = ' '.join(lineelements)
        similars.append(element)
        
    elif 'categories' == lineelements[0]:
        num_categories.append(lineelements[1])
        lastcat = True
        cats = []
        cnt = 0
        for i in range(int(lineelements[1])):
            l = text.readline()
            cats.append('|'.join(l.split('|')[2:]).strip())
        categories.append(cats)
    elif 'reviews' == lineelements[0]:
        review = ':'.join(lineelements[1:]).strip()
        reviews.append(review)
        sub = review.split()
        subsub = [x.split(':') for x in sub]
        r = []
        for i in range(int(subsub[1][1])):
            l = text.readline()
            r.append(l)
        reviewinfo.append(r)

# %%
data = {'ID':Ids, 
        'ASIN':ASINs, 
        'title':titles, 
        'group':groups, 
        'salesrank':salesranks, 
        'similar':similars, 
        'num_categories':num_categories, 
        'categories':categories,
        'review':reviews, 
        'reviewinfo':reviewinfo}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#   ID        ASIN                                             title group  \
# 0  1  0827229534                             Patterns of Preaching  Book
# 1  2  0738700797                                         Candlemas  Book
# 2  3  0486287785  World War II Allied Fighter Planes Trading Cards  Book
# 3  4  0842328327                 Life Application Bible Commentary  Book
# 4  5  1577943082              Prayers That Avail Much for Business  Book
#
#   salesrank                                            similar num_categories  \
# 0    396585  5  0804215715  156101074X  0687023955  0687074...              2
# 1    168596  5  0738700827  1567184960  1567182836  0738700...              2
# 2   1270652                                                  0              1
# 3    631289  5  0842328130  0830818138  0842330313  0842328...              5
# 4    455160  5  157794349X  0892749504  1577941829  0892749...              2
#
#                                           categories  \
# 0  [Subjects[1000]|Religion & Spirituality[22]|Ch...
# 1  [Subjects[1000]|Religion & Spirituality[22]|Ea...
# 2  [Subjects[1000]|Home & Garden[48]|Crafts & Hob...
# 3  [Subjects[1000]|Religion & Spirituality[22]|Ch...
# 4  [Subjects[1000]|Religion & Spirituality[22]|Ch...
#
#                                     review  \
# 0      total:2  downloaded:2  avg rating:5
# 1  total:12  downloaded:12  avg rating:4.5
# 2      total:1  downloaded:1  avg rating:5
# 3      total:1  downloaded:1  avg rating:4
# 4      total:0  downloaded:0  avg rating:0
#
#                                           reviewinfo
# 0  [    2000-7-28  cutomer: A2JW67OY8U6HHK  ratin...
# 1  [    2001-12-16  cutomer: A11NCO6YTE4BTJ  rati...
# 2  [    2003-7-10  cutomer: A3IDGASRQAW8B2  ratin...
# 3  [    2004-8-19  cutomer: A2591BUPXCS705  ratin...
# 4                                                 []

# %% [markdown]
# ####Saving features extracted from the dataset for future use-cases

# %%
df.to_csv('/content/extracteddata.csv')

# %% [markdown]
# ### 1.2. Feature Extraction and Dataset Creation

# %%
# %%bash
# !pip install fsspec
# pip install dask[dataframe]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.7/dist-packages (2.12.0)
# Requirement already satisfied: toolz>=0.7.3 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]) (0.11.2)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]) (1.3.5)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]) (1.21.6)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.0->dask[dataframe]) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.0->dask[dataframe]) (2022.1)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23.0->dask[dataframe]) (1.15.0)
# Installing collected packages: locket, partd, fsspec
# Successfully installed fsspec-2022.5.0 locket-1.0.0 partd-1.2.0
# bash: line 1: !pip: command not found

# %%
import dask.dataframe as dd

# %% [markdown]
# ##### Helper Functions

# %%
def extractrating(x):
    reviewsplit = x['review'].split()
    y = float(reviewsplit[3].split(':')[1])
    return y

# %%
def extractdownloads(x):
    reviewsplit = x['review'].split()
    num = int(reviewsplit[1].split(':')[1])
    return num

# %%
def extracttotal(x):
    reviewsplit = x['review'].split()
    num = int(reviewsplit[0].split(':')[1])
    return num

# %%
df = dd.read_csv('/content/extracteddata.csv').set_index('Unnamed: 0')

# %% [markdown]
# #### Using Dask for handling large scale data pre-processing using capabilities of parallel processing

# %%
df1 = df.copy()
df1['totalreviews'] = df1.apply(extracttotal, axis =1, meta = ('totalreviews', 'i8'))
df1['downloadedreviews'] = df1.apply(extractdownloads, axis = 1, meta = ('downloadedreviews', 'i8'))
df1['avg_rating'] = df1.apply(extractrating, axis = 1, meta = ('avg_rating', 'i8'))
df1 = df1.drop('review', axis = 1)
df1 = df1.reset_index().drop('Unnamed: 0', axis = 1)
df1.ID = df1.ID.astype('int64')
df1.salesrank = df1.salesrank.astype('int64')
df1.num_categories = df1.num_categories.astype('int64')
df1.head()
# Out:
#    ID        ASIN                                             title group  \
# 0   1  0827229534                             Patterns of Preaching  Book
# 1   2  0738700797                                         Candlemas  Book
# 2   3  0486287785  World War II Allied Fighter Planes Trading Cards  Book
# 3   4  0842328327                 Life Application Bible Commentary  Book
# 4   5  1577943082              Prayers That Avail Much for Business  Book
#
#    salesrank                                            similar  \
# 0     396585  5  0804215715  156101074X  0687023955  0687074...
# 1     168596  5  0738700827  1567184960  1567182836  0738700...
# 2    1270652                                                  0
# 3     631289  5  0842328130  0830818138  0842330313  0842328...
# 4     455160  5  157794349X  0892749504  1577941829  0892749...
#
#    num_categories                                         categories  \
# 0               2  ['Subjects[1000]|Religion & Spirituality[22]|C...
# 1               2  ['Subjects[1000]|Religion & Spirituality[22]|E...
# 2               1  ['Subjects[1000]|Home & Garden[48]|Crafts & Ho...
# 3               5  ['Subjects[1000]|Religion & Spirituality[22]|C...
# 4               2  ['Subjects[1000]|Religion & Spirituality[22]|C...
#
#                                           reviewinfo  totalreviews  \
# 0  ['    2000-7-28  cutomer: A2JW67OY8U6HHK  rati...             2
# 1  ['    2001-12-16  cutomer: A11NCO6YTE4BTJ  rat...            12
# 2  ['    2003-7-10  cutomer: A3IDGASRQAW8B2  rati...             1
# 3  ['    2004-8-19  cutomer: A2591BUPXCS705  rati...             1
# 4                                                 []             0
#
#    downloadedreviews  avg_rating
# 0                  2         5.0
# 1                 12         4.5
# 2                  1         5.0
# 3                  1         4.0
# 4                  0         0.0

# %% [markdown]
# #### Extracting Review Information identified by product Id

# %%
df2 = df1[['ID', 'reviewinfo']].copy()
df2.reviewinfo = df2.reviewinfo.str.strip('][').str.replace("'", '').str.split(',')
df2 = df2.explode('reviewinfo').reset_index()
df2 = df2.drop(['index'], axis = 1)
df1 = df1.drop('reviewinfo', axis = 1)
df2.head()
# Out:
#    ID                                         reviewinfo
# 0   1      2000-7-28  cutomer: A2JW67OY8U6HHK  rating...
# 1   1       2003-12-14  cutomer: A2VE83MZF98ITY  rati...
# 2   2      2001-12-16  cutomer: A11NCO6YTE4BTJ  ratin...
# 3   2       2002-1-7  cutomer:  A9CQ3PLRNIR83  rating...
# 4   2       2002-1-24  cutomer: A13SG9ACZ9O5IM  ratin...

# %% [markdown]
# #### Extracting Categories Information identified by product Id

# %%
df3 = df1[['ID', 'categories']].copy()
df3['categories'] = df3.categories.str.strip('][').str.replace("'", '').str.split(',')
df3 = df3.explode('categories').reset_index()
df3 = df3.drop('index', axis = 1)
df1 = df1.drop(['categories'], axis = 1)
df3.head()
# Out:
#    ID                                         categories
# 0   1  Subjects[1000]|Religion & Spirituality[22]|Chr...
# 1   1   Subjects[1000]|Religion & Spirituality[22]|Ch...
# 2   2  Subjects[1000]|Religion & Spirituality[22]|Ear...
# 3   2   Subjects[1000]|Religion & Spirituality[22]|Ea...
# 4   3  Subjects[1000]|Home & Garden[48]|Crafts & Hobb...

# %% [markdown]
# #### Extracting Similar Products Information identified by product Id

# %%
df4 = df1[['ID', 'similar']].copy()
df4.similar = df4.similar.str.split()
df4 = df4.reset_index().drop('index', axis =1)
df1 = df1.drop('similar', axis = 1)
df4.head()
# Out:
#    ID                                            similar
# 0   1  [5, 0804215715, 156101074X, 0687023955, 068707...
# 1   2  [5, 0738700827, 1567184960, 1567182836, 073870...
# 2   3                                                [0]
# 3   4  [5, 0842328130, 0830818138, 0842330313, 084232...
# 4   5  [5, 157794349X, 0892749504, 1577941829, 089274...

# %% [markdown]
# #### Saving Dataframes for further analysis

# %%
df1.compute().to_csv('/content/finalpreprocesseddata.csv', index = False)
df2.compute().to_csv('/content/reviews.csv', index = False)
df3.compute().to_csv('/content/categories.csv', index = False)
df4.compute().to_csv('/content/similar.csv', index = False)

# %% [markdown]
# ## 2.Implementing a recommendation System based on the extracted features using Similarity Measures

# %%
"""from google.colab import drive
drive.mount('/content/drive')"""
# Out:
# "from google.colab import drive\ndrive.mount('/content/drive')"

# %% [markdown]
# ### Creating a Directed graph from the given edgelist

# %%
Graphtype = nx.DiGraph()
filepath = '/content/amazon0601.txt'
G = nx.read_edgelist(
    filepath,
    comments='#',
    create_using=Graphtype,
    nodetype=int
)

# %% [markdown]
# #### Reading Metadata

# %%
df = pd.read_csv('/content/finalpreprocesseddata.csv')

# %%
df.head()
# Out:
#    ID        ASIN                                             title group  \
# 0   1  0827229534                             Patterns of Preaching  Book
# 1   2  0738700797                                         Candlemas  Book
# 2   3  0486287785  World War II Allied Fighter Planes Trading Cards  Book
# 3   4  0842328327                 Life Application Bible Commentary  Book
# 4   5  1577943082              Prayers That Avail Much for Business  Book
#
#    salesrank  num_categories  totalreviews  downloadedreviews  avg_rating
# 0     396585               2             2                  2         5.0
# 1     168596               2            12                 12         4.5
# 2    1270652               1             1                  1         5.0
# 3     631289               5             1                  1         4.0
# 4     455160               2             0                  0         0.0

# %% [markdown]
# ##### Checking and Dropping Null Values

# %%
df.isnull().sum()
df = df.dropna()

# %%
df['group'].value_counts()
# Out:
# Book            393559
# Music           103144
# Video            26131
# DVD              19828
# Toy                  8
# Software             5
# CE                   4
# Video Games          1
# Baby Product         1
# Sports               1
# Name: group, dtype: int64

# %% [markdown]
# #####Indexing the graph on the attribute 'ID'

# %%
df = df.set_index('ID')

# %% [markdown]
# #### Selecting Attributes that each nodes will have

# %%
nodeattrdf = df[['ASIN','title','group', 'num_categories','salesrank', 'totalreviews', 'downloadedreviews', 'avg_rating']].copy()

# %% [markdown]
# #### Combining the transaction data and the metadata into a networkX Directed Graph

# %%
nx.set_node_attributes(G, nodeattrdf.to_dict('index'))

# %%
G.nodes[8]
# Out:
# {'ASIN': '0231118597',
#  'avg_rating': 4.5,
#  'downloadedreviews': 15,
#  'group': 'Book',
#  'num_categories': 4,
#  'salesrank': 277409,
#  'title': 'Losing Matt Shepard',
#  'totalreviews': 15}

# %% [markdown]
# ####**Empty nodes/Disjoint nodes do not contribute significantly when we recommended products.So we have removed them**

# %%
remove = [nodes for nodes in dict(G.nodes()) if len(G.nodes[nodes]) == 0]

# %%
G.remove_nodes_from(remove)

# %% [markdown]
# Here, n is the array of all non-deleted nodes in the graph

# %%
n = list(G.nodes)

# %%
n =  np.array(n)
n = np.unique(n)

# %% [markdown]
# ##### Helper function to retrive all target nodes from the edges starting from the source

# %%
def getclean(pro_id):    
    l = str(list(G.edges(pro_id)))
    l = l.replace('[','')
    l = l.replace(']','')
    l = l.replace(',','')
    l = l.replace('(','')
    l = l.replace(')','')
    l = l.replace(str(pro_id)+" ", '')
    b = l.split()
    b = np.array(b)
    b = b.astype(int)
    return b

# %%
G.edges(5)
# Out:
# OutEdgeDataView([(5, 6), (5, 44), (5, 46), (5, 47), (5, 48), (5, 49), (5, 50), (5, 51), (5, 52), (5, 53)])

# %%
getclean(5)
# Out:
# array([ 6, 44, 46, 47, 48, 49, 50, 51, 52, 53])

# %% [markdown]
# ####Function for user to search for a product

# %%
def search(s):
  s = s.lower()
  indx = df.index[(df['title'].str.contains(s, case = False))==True]   
  indx = np.array(indx)
  indx = indx.astype(int)
  return indx

# %% [markdown]
# Storing array of indexes in an array

# %%
iarray = search(str(input()))
print(len(iarray))

for i in range(0, len(iarray)):
  if(iarray[i] in n):
    print(iarray[i], G.nodes[iarray[i]]['title'])
# Out:
# Streaming output truncated to the last 5000 lines.
# 47498 Special Edition Using Filemaker Pro 5
# 47545 Maps, Charts, Graphs Gr 5 Student Edition
# 47546 365 Foods Kids Love to Eat
# 47575 Confieso Que He Vivido (Ave Fenix, 205/1)
# 47619 Jessi's Horrible Prank (Baby-Sitters Club, 75)
# 47728 The Dynamics of Military Revolution, 1300-2050
# 47743 Greenberg's Repair and Operating Manual for Lionel Trains, 1945-1969 (Greenberg's Repair and Operating Manuals)
# 47856 1950-1951
# 47881 Essentials of European History, 1914-1935 (Essentials)
# 47898 French Three Years Workbook (R 588 W)
# 48006 Section 504 in the Classroom
# 48044 Ward No. 6 and Other Stories, 1892-1895 (Penguin Classics)
# 48193 Piaget's Theory of Cognitive and Affective Development/Foundations of Constructivism (5th Edition)
# 48196 The 1949-1959 VW Beetle (Authenticity Series)
# 48293 A Short Course in Nikon Coolpix 5000 Photography
# 48354 What a Year It Was! 1955
# 48387 5-HTP
# 48466 An Experiential Approach to Organization Development (5th Edition)
# 48499 25 Greatest Hot Fives & Sevens
# 48525 Windows on a Lost World (Star Trek, Book 65)
# 48556 Masterpieces of Italian Violin Making (1620-1850)
# 48640 Exploring the Philosophy of Religion (5th Edition)
# 48671 NFL's Greatest Ever Vol. 5 - Running Backs
# 48742 Our 25th Year
# 48796 Doctor Who - The Scripts, Tom Baker 1974-5
# 48821 500th Anniversary
# 48940 50 Irish Drinking Songs
# 48993 145th Street
# 49069 The Blob That Ate Everyone (Goosebumps, No 55)
# 49086 Observing Development of the Young Child (5th Edition)
# 49097 The French Army 1939-45 (2)
# 49157 The Golden Road (1965 - 1973)
# 49260 Bmw 5 Series (Car & Motorcycle Marque/Model)
# 49269 Syllabus 5th Halley Radiological Refresher Course
# 49450 Lonely Planet Scandinavian & Baltic Europe (Scandinavian and Baltic Europe, 5th ed)
# 49524 How to Rebuild and Modify Your Porsche 911 Engine 1965-1989
# 49546 Karate By Fumio Demura Vol.05
# 49607 Three Miracles, The  Adventures of Andi O'Malley, 4.) (Adventures of Andi O'Malley, 5)
# 49644 Snoopy!!! The New Musical Entertainment (1975 San Francisco Cast)
# 49817 Battletech 50
# 49880 This Is Me [CD5]
# 49933 Silent Songs (Starbridge, Book 5)
# 49982 On the Beach at Waikiki (1914-52)
# 50010 Prince and Future...Dad? (Silhouette Special Edition No. 1556) (Viking Brides series)
# 50035 The Penguin Guide to Jazz on CD (Penguin Guide to Jazz on CD, 5th ed)
# 50197 25/5/00 - Palau Sant Jordi, Barcelona, Spain
# 50369 A L'olympia 1985
# 50675 A Different Mix Volumes 1 - 5
# 50679 The Heart (Netter Collection of Medical Illustrations, Volume 5)
# 50837 Top Tunes Karaoke CDG Gal Pop Vol. 30 TT--150
# 50949 Little 15 [#2]
# 50974 The Essential 55
# 51007 Las nuevas profecías de Nostradamus hasta el año 2025
# 51011 Civil Rights, the White House, and the Justice Department, 1945-1968
# 51027 25 Aniversario (1971-96)
# 51056 Video Girl Ai, Vol. 5
# 51094 GM Full-Size Buick, Oldsmobile, and Pontiac, 1975-90 (Chilton's Total Car Care Repair Manual)
# 51397 Build Your Baby's Brain 5
# 51490 American Modern, 1925-1940
# 51507 25 Year Celebration Mannheim Steamroller
# 51659 Michelin Benelux (Belgium, The Netherlands, Luxembourg) Map No. 907, 5e
# 51873 Susana Y Javier En Espana (12-25397)
# 51885 Lotus Notes R5 Fast & Easy (Fast & Easy)
# 52147 Dragon Ball Z - The Namek Saga (Boxed Set II - Episodes 26-53)
# 52148 Microsoft Exchange Server 5.5 Administrator's Companion
# 52149 Managing and Maintaining Microsoft Exchange Server 5.5
# 52371 Summerhill Secrets (Summerhill Secrets Series , Vol 1-5)
# 52375 A Review of Books, Studies and Journal Articles Published in the U.S.A. from 1955-1995 Relating to the Sociological Impact of Corporate Relocation on the Family System
# 52422 Crossing the Plains to Oregon in 1853
# 52425 (Quinn's Way (Harlequin American Romance, No. 558)
# 52478 The 500 Hats of Bartholomew Cubbins (Classic Seuss)
# 52575 50 Writing Lessons That Work!
# 52635 50 Ways to Feed Your Lover
# 52649 1951 Celebration
# 52727 FitPrime Volume 5
# 52807 Software Construction and Data Structures with Ada 95 (2nd Edition)
# 52957 Corporate Therapy and Consulting (Mental Health Practice Under Managed Care, Vol 5)
# 53058 Understanding Basic Electronics (Publication No. 159 of the Radio Amateur's Library)
# 53094 Sams Teach Yourself Microsoft Exchange Server 5.5 in 10 Minutes
# 53114 Doo Wop at 50 Two Pak
# 53165 Jagdpanzer 38t Hetzer, 1944-45 (New Vanguard Series, 36)
# 53188 German E-Boats 1939-45 (New Vanguard 59)
# 53204 Anthology 1965 - 1969
# 53240 King Guezo of Dahomey 1850-52
# 53333 Best of 1955-1960
# 53505 The Women of Provicetown, 1915-1922
# 53627 50 Secrets
# 53630 Manhattan for Rent, 1785-1850
# 53644 1952
# 53689 Violence & Terrorism 99/00 (Violence and Terrorism, 5th ed)
# 53717 Women and Literature in Britain, 1150-1500 (Cambridge Studies in Medieval Literature)
# 53779 Mach 5
# 53909 Mosaics of Antioch (Subsidia Mediaevalia, No 15)
# 53943 Anthology, Vol. 1-2 (1956-1980)
# 54004 The 25-Year War
# 54183 Microsoft Visual Studio Core Reference Set (Microsoft Professional Editions , So5)
# 54252 Soul Hunter - City of Fire (Vol. 5)
# 54332 Autodesk Inventor R5 Fundamentals w/Multi-Media Extension
# 54364 Alive '95 [Bonus Tracks]
# 54497 Berenstain Bears Vol. 5
# 54569 50 Simple Steps You Can Take to Sell Your Home Faster and for More Money in Any Market
# 54614 Kawasaki Kz400, Kz/Z440, En450 & En500, 1974-1995
# 54712 Magik, Vol. 5
# 54745 Women Poets of China (New Directions Paperbook, 528)
# 54888 Deltora Quest #05
# 55002 Unbelievably Good Deals and Great Adventures that you Absolutely Can't Get Unless You're Over 50 (Unbelievably Good Deals)
# 55006 Americans and the California Dream, 1850-1915
# 55092 British and Empire Aces of World War I (Osprey Aircraft of the Aces No 45)
# 55095 Days with Frog and Toad 25th Anniversary Edition (I Can Read Book 2)
# 55566 There's Only Now + 5 (Ltd)
# 55665 Faeries (25th Anniversary Edition)
# 55922 The 1912 and 1915 Gustav Stickley Craftsman Furniture Catalogs
# 56082 Time Passages 1953 Yearbook (Time Passages)
# 56266 Indians in Pennsylvania (Anthropological Series (Pennsylvania Historical and Museum Commission), No 5)
# 56467 The Secret of the Forgotten City (Nancy Drew Mystery Stories, No 52)
# 56487 Playboy - 1995 Playmate of the Year Julie Lynn Cialini, Video Centerfold
# 56534 Fieseler Fi 156 Storch (Schiffer Military History)
# 56538 Sun Certified Programmer for Java 2 Study Guide (Exam 310-025)
# 56573 Fiat 500 Owners Workshop Manual
# 56599 Gifts to the Tzars 1500-1700
# 56634 The Gods of Riverworld (Riverworld Saga, No 5)
# 56671 How Big 'A Boy Are Ya?, Vol. 5
# 56724 Verve Jazz Masters 50
# 56725 Verve Jazz Masters 45
# 56832 Doo Wop 51
# 56928 S&P 500 Trading Mastery
# 57116 Star Trek - The Next Generation, Episode 75
# 57125 Give Yourself Goosebumps Boxed Set, Books 5 - 8
# 57171 1959
# 57173 25 Gorgeous Sweaters for the Brand-New Knitter
# 57179 365 Quick Cross Stitch Christmas Designs
# 57230 52 Special Traditions for Family and Friends (52 Deck Series)
# 57290 Elvis 56
# 57317 The Music from Peter Gunn (1958-1961 TV Series)
# 57498 Partita 5 in G Major / Sinfonias / Concerto in D
# 57538 Sams Teach Yourself Lotus Notes 5 in 10 Minutes
# 57567 Babylon 5, Season 5 - Interstellar Alliance
# 57934 Florida Real Estate Exam Manual (Florida Real Estate Exam Manual, 25th ed)
# 57955 365 Amazing Trivia Facts Page-A-Day Calendar 2002
# 57977 50 Hikes in Vermont
# 57998 Channeling Companion (#5604)
# 58080 16 Sweet Tunes of the Fantastic '50s
# 58358 Adult Development and Aging (5th Edition)
# 58518 Jump5
# 58690 Battle of the Planets (Vol. 5)
# 58691 Saint Tail - Girl of Justice (Vol. 5)
# 58750 The Fall of Berlin 1945
# 58777 Maya 4.5 for Windows and Macintosh
# 58782 Volkswagen Scirocco, Cabriolet Service Manual 1985, 1986, 1987, 1988, 1989 Including 16v (Volkswagen Service Manuals)
# 58855 The New Yoga for People Over 50
# 59027 Rag Todi in Concert Calcutta 1957
# 59035 Rambler  1950-1969 Photo Archive
# 59158 365 Buddha
# 59200 Billboard's Top Pop Albums 1955-2001
# 59228 Junie B. Jones and the Yucky Blucky Fruitcake (Junie B. Jones 5, paper)
# 59246 A Photo Album of Ohio's Canal Era, 1825-1913 (Ohio)
# 59411 1959-1963 V.2
# 59508 A History of the Soviet Union 1945-1991
# 59681 Symphony No. 5 in C-Sharp Minor (Dover Miniature Scores)
# 59694 Twilight of Terror (Ragnarok, Vol. 5)
# 59755 A Christmas Carol (1995 Original Broadway Cast)
# 59763 Concise Anthology of American Literature (5th Edition)
# 59923 The Struggle for the American Curriculum 1893-1958
# 59964 354th Fighter Group (Osprey Aviation Elite 7)
# 60042 Hans Christian Andersen (1952 Film) / The Court Jester (1956 Film) [2 on 1]
# 60070 1985
# 60352 Hollywood 1900-1950 In Vintage Postcards
# 60363 What Would You Do [CD5/Cassette]
# 60364 15 Easy-To-Read Mini Book Plays
# 60387 Complete Idiot's Guide to Macromedia Flash 5
# 60418 Word Biblical Commentary Vol. 50, 2 Peter, Jude  (bauckham), 377pp
# 60589 The Best of Sergio Mendes & Brasil '65
# 60631 Radiowave Propagation and Smart Antennas for Wireless Communications (The Kluwer International Series in Engineering and Computer Science Volume 599)  ... l Series in Engineering and Computer Science)
# 60681 Thoroughbred #15 Glory's Triumph (Thoroughbred)
# 60743 Formula 51
# 60860 The 150 Best Slow Cooker Recipes
# 60922 Methods and Environmental Psychology (Advances in Environmental Psychology, Vol 5)
# 61091 Rockjaw, Master of the Eastern Border (Bone, Book 5)
# 61245 Fun-Filled 5-to 10-Minute Science Activities for Young Learners (Grades PreK-1)
# 61310 Topics and Language Competencies Level 5
# 61390 WCBS FM 101.1 25th Anniversary, Vol. 2
# 61439 Sun Certification Training Guide (CS-310-025 & CX-310-027)
# 61450 The Giant Encyclopedia of Theme Activities for Children 2 to 5
# 61466 Word Biblical Commentary Vol. 35b, Luke 9
# 61482 How to Plan and Remodel Attics and Basements/05926 (Ortho Books)
# 61566 Visual Basic 5 Night School (3rd Edition)
# 61568 The Habsburg Monarchy, 1618-1815 (New Approaches to European History)
# 61572 50 Simple Things Kids Can Do to Save the Earth
# 61620 PASSTRAK Life and Health Insurance Licesne Exam Manual, 5E
# 61704 50's Masters
# 61710 1952-55
# 61739 The Lost Road and Other Writings (The History of Middle-Earth, Vol. 5)
# 61795 The Official 2003 Blackbook Price Guide to United States Paper Money,35th Edition (Official Blackbook Price Guide to United States Paper Money)
# 61865 Zohar (5 Volume set)
# 61866 365 Great Barbeque and Grill Anniversary Edition
# 61898 Santa Barraza, Artist of the Borderlands (Rio Grande/Rio Bravo, No. 5)
# 62023 The Civil War 1861-65
# 62100 Outernet #5 (Outernet)
# 62134 Reading Architectural Plans for Residential and Commercial Construction (5th Edition)
# 62153 Ready-To-Use Physical Science Activities for Grades 5-12 (Secondary Science Curriculum Activities Library)
# 62235 Symphonies 4 & 5
# 62247 ASE Test Prep Series -- Automobile (A5)
# 62259 Loving Thy Neighbor (Love Inspired, No. 145)
# 62307 Charmed #15
# 62410 Amethyst and Gold (Bouquet #5)
# 62413 The Boeing C-135 Series
# 62454 Search My Heart, O God 365 Appointments with God
# 62502 Take 5 Quartet
# 62711 25th Anniversary Swimsuit
# 62732 Cultural Dimensions of International Mergers and Acquisitions (De Gruyter Studies in Organization, No. 85) (De Gruyter Studies in Organization , No 85)
# 62773 A Child's Story of America (79945)
# 62935 Return of the 5 Deadly Venoms
# 63004 Complete set of Hebrew-English-Hebrew Dictionary (5 Volumes)
# 63007 25 Praise and Worship Favorites for Easy Guitar - Volume 2
# 63060 The Sheikh's Chosen Wife  (Hot-Blooded Husbands) (Harlequin Presents, 2254)
# 63202 A History of the Guyanese Working People, 1881-1905 (The Johns Hopkins Studies in Atlantic History and Culture)
# 63260 Board Games of the 50'S, 60'S, & 70's
# 63293 America Views the Holocaust, 1933-1945
# 63345 The Habsburg Monarchy, C. 1765-1918
# 63454 (4530) An Ordinary of Arms Contained in the Public Register of All Arms and Bearings in Scotland 2nd edition
# 63477 Along Interstate 75 (Along Interstate 75, 10th ed)
# 63670 MENSA 365 Brain Puzzlers Page-A-Day Calendar 2002
# 63740 50 Classic Backcountry Ski and Snowboard Summits in California
# 63781 Experimental Television, Test Films, Pilots, and Trial Series, 1925 Through 1995
# 63910 Hits of 1985
# 63946 100 Bullets Vol. 5
# 63992 Gold Diggers of 1935
# 64271 The Buck Owens Collection (1959-1990)
# 64341 Practical Criminal Investigation (5th. Ed.)
# 64349 Harrison's Manual of Medicine, 15/e for PDA
# 64408 Grumpy Pumpkins (Pee Wee Scouts Number 5)
# 64527 250 Stencil Designs from India (Dover Design Library)
# 64619 Guide to Cytochromes P450
# 64772 The Lost Films of Laurel & Hardy - The Complete Collection, Vol. 5
# 64797 The C.I.A. and the U-2 Program, 1954-1974 (Top Secret (New Century))
# 64800 Spoons, 1650-1930
# 64914 Powerpuff Girls 8x8 #05
# 64942 The 5 Minute Veterinary Consult
# 64967 The Power of the Flower [CD5]
# 65051 Pediatrics 5-Minute Reviews, 2001-2002 Edition
# 65114 Michelin Italy Map No. 988, 25e
# 65135 His Majesty, M.D. (Man Of The Month/The Royal Dumonts) (Desire, 1435)
# 65251 CCNA Cisco Certified Network Associate Study Guide (Exam 640-507), Second Edition
# 65252 Workbook/Study Guide II (Lessons 27-52) to accompany Destinos
# 65340 Agincourt 1415
# 65363 Getting Started with MATLAB 5, A Quick Introduction for Scientists and Engineers
# 65420 Nightfire (The Executioner #259) (The Executioner, 259)
# 65458 English Prose of the 17th Century, 1590-1700 (Longman Literature in English Series)
# 65488 Literature and Ideology in Haiti, 1915-1961
# 65524 Argentina, 1516-1987
# 65559 Economic Control of Quality of Manufactured Product/50th Anniversary Commemorative Issue
# 65777 Chinatown (25th Anniversary Edition)
# 65785 Chinatown (25th Anniversary Widescreen Edition)
# 65899 Moto Guzzi 750, 850 and 1000 V-Twins
# 66044 Negotiating International Hotel Chain Management Agreements a Primer for Hotel Owners Dev Countries (Unctc Advisory Studies, No 5, Series B/E90 Iia)
# 66053 Damn Yankees (1955 Original Broadway Cast)
# 66088 Populations in a Seasonal Environment. (MPB-5) (Monographs in Population Biology)
# 66105 1956-60
# 66153 Word Biblical Commentary Vol. 31, Hosea-jonah  (stuart), 583pp
# 66510 Users' Guide to Logic Audio 5 (Users' Guide To...)
# 66542 Jagdgeschwader 54
# 66848 Draw 50 Aliens (Draw 50)
# 66934 The Tuscarawas Valley in Indian Days 1750-1797
# 66949 Hidden Southwest (Hidden Southwest, 5th ed)
# 67044 57 More of the Best Chocolate Chip Cookies in the World
# 67106 GoLive 5 for Dummies
# 67115 Adobe(R) Acrobat(R) 5.0 Classroom in a Book
# 67131 Cessna 150 (A Pilot's Guide)
# 67181 Photoshop 5.5
# 67183 Armies of the Ottoman Empire 1775-1820 (Men-At-Arms, No 314)
# 67334 3ds max 5 Bible
# 67427 Indonesia Crisis and Transformation 1965-1968
# 67560 The 25th Hour
# 67822 Goofy Mad Libs (Mad Libs No 5)
# 67823 The 5-Minute Veterinary Consult
# 67924 Celtic Twilight, Vol. 5
# 68071 Mac OS X Administration Basics Exam Cram (Exam 9L0-500)
# 68126 Carousel (1956 Film Soundtrack)
# 68128 The King and I (1956 Film Soundtrack)
# 68130 Oklahoma! (1955 Film Soundtrack)
# 68269 Marc Brown's Arthur Volume V (Marc Brown's Arthur, 5)
# 68316 50 Tips for Speaking Like a Pro
# 68328 Best of Business Card Design 5
# 68400 Longarm and the Denver Executioners (Longarm, 275)
# 68455 The Best 345 Colleges, 2003 Edition (Princeton Review Series)
# 68484 Harlequin 50th Anniversary Collection #2
# 68492 53 Ways to Use Noni Fruit Juice
# 68511 Columbus, Ohio 1898-1950
# 68536 Manumission (Soundtrack - including 5 Minute trailer for the film)
# 68651 Rossback and Leuthen 1757
# 68667 The Goddess of 5th Avenue
# 68670 MCSE Microsoft Windows 2000 Server Readiness Review (Exam 70-215)
# 68671 Christy Series #5
# 68745 Private Pilot Manual (JS314500)
# 68814 Decorate a Snowman With 35 Stickers
# 68861 Ricky Nelson - 25 Greatest Hits
# 68863 Little Anthony & the Imperials - 25 Greatest Hits
# 68902 Liberty for All? 1800-1860 (History of U.S., Book 5)
# 69149 Art in Germany 1933-1945
# 69261 Junie B. Jones Has a Peep In Her Pocket (Junie B. Jones 15, paper)
# 69427 My People's Prayer Book, Vol. 5
# 69594 1935-1936
# 69600 Mixing in Estuaries and Coastal Seas (Coastal and Estuarine Studies, 50)
# 69694 Yanmar Inboards 1975-98
# 69705 Franklin D. Roosevelt and American Foreign Policy, 1932-1945
# 69728 Earl Wild Plays Liszt (The 1985 Sessions)
# 69935 Natural Hormone Replacement For Women Over 45
# 69999 El Encaje Roto Y Otros Cuentos ((Mla Texts & Translations Ser. Vol. 5a))
# 70048 You Can Make It - Learn To Sew - Level 5
# 70140 5 a Day
# 70166 Eleanor Roosevelt, 1942-1945 (Camp David Diaries, Vol. 1) (Camp David Diaries)
# 70383 52 Illinois Weekends
# 70419 The Complete Historical and Statistical Reference to the World Hockey Association, 1972-1979 (5th Printing)
# 70426 On the Short Waves, 1923-1945
# 70437 Talking from 9 to 5
# 70520 450 More Story S-T-R-E-T-C-H-E-R-S for Primary Grades
# 70651 International Harvester Tractors 1955-1985 (Motorbooks International Farm Tractor Color History)
# 70764 R&B Hits 1952
# 70773 Zoids - The Shadow Battle (Vol. 5)
# 70800 Salvation Road (Deathlands, No. 58)
# 70969 Cowboy Protector  (The McKenna Legacy) (Harlequin Intrigue Series, 665)
# 71110 The First European Revolution, C. 970-1215 (Making of Europe)
# 71165 How to Use America Online 5 (Other Sams)
# 71256 Why Should I Care [CD5 Single]
# 71405 Hispanic Arizona, 1536-1856
# 71406 The Many Adventures of Winnie the Pooh (25th Anniversary Edition)
# 71418 The Heritage of World Civilization, Combined (5th Edition)
# 71517 Psychology 5th Edition Study Guide
# 71662 25 Top Vineyard Worship Songs
# 71705 International Economics, 5th Edition
# 71765 French Foreign Legion Operations 1990-2000 Europa Military Special #15
# 71930 Talon and Fang  (Outlanders #25)
# 71951 CCNP(TM) Support Study Guide (Exam 640-506)
# 72014 El Arbol y La Serpiente (25 Anos de Investigacion)
# 72230 The Shakespearean Stage, 1574-1642
# 72247 Flavonoids and Other Polyphenols (Methods in Enzymology, Vol 335) (Methods in Enzymology)
# 72326 A Battle History of the Imperial Japanese Navy, 1941-1945
# 72349 Princes, Politics, and Religion, 1547-1589 (History Series, 30)
# 72362 Into Battle (The Seventh Tower, Book 5)
# 72477 Hitler's Secret War in South America, 1939-1945
# 72488 Chronology of Late Cretaceous Igneous and Hydrothermal Events at the Golden Sunlight Gold-Silver Breccia Pipe, Southwestern Montana (U.S. Geological Survey Bulletin, 2155)
# 72568 1944-1945
# 72692 The Harrison Ford Collection (Witness, Sabrina '95, Patriot Games, Clear and Present Danger)
# 72747 Todaysgirls.com #5
# 72817 Handbook of Nonlinear Optics (Optical Engineering Series, Vol 52)
# 72844 Selected Ambient Works 85-92
# 72916 Sailor Moon S - Back from the Future (Vol. 5, Uncut Version)
# 72999 Richter Collection 5
# 73038 The Horse Soldier 1851-1880
# 73093 50 Fast Digital Photo Techniques
# 73097 501 Backgammon Problems
# 73215 14 Vallenatos Romanticos, Vol. 5
# 73268 Concepts of Programming Languages (5th Edition)
# 73336 115 Saintly Fun Facts
# 73365 Babylon 5 - Season 2 - The Long Dark/Spider in the Web
# 73417 25th Anniversary
# 73486 Trans-Siberian Handbook, 5th
# 73495 International News & Foreign Correspondence (Hess, Stephen. Newswork, 5.)
# 73533 Americans in Kodachrome 1945-1965
# 73658 1500 Illustrations for Biblical Preaching
# 73773 Chris-Craft in the 1950s
# 74100 The Kids' Book of the 50 Great States (Grades 3-6)
# 74229 Successful Strategic Planning (50-Minute Series)
# 74287 Comden And Green Perform Their Own Songs [2 Original 1955 Albums On 1]
# 74373 Stranger In Room 205 (Hot Off The Press) (Silhouette Special Edition, No 1399)
# 74416 Michael Coleman 1891-1945
# 74450 Tyler #5
# 74480 OpenGL Programming for Windows 95 and Windows NT
# 74515 AIX 5L Administration
# 74550 Star Trek - The Original Series, Vol. 28, Episodes 55 & 56
# 74552 Star Trek - The Original Series, Vol. 27, Episodes 53 & 54
# 74686 Harrison's Principles of Internal Medicine, 15th Edition
# 74700 Adventures of the Northwoods/1-5 Boxed Set
# 74778 WebObjects 5 for Mac OS X
# 74932 An Introduction to the Siswati Language Lesson and Glossary/91005
# 74955 The Best 50 Salad Dressings (Best 50)
# 74969 NetWare 5 CNE
# 75027 Family Knits--Over 25 Versatile Designs for Babies, Children and Adults
# 75072 How to Sell Your Home in 5 Days
# 75205 PageMaker 6.5 for Macintosh (Visual QuickStart Guide)
# 75218 Frye's 2500 Nursing Bullets for NCLEX-RN
# 75245 Star Trek - The Original Series, Episode 59
# 75275 Sailing Alone Around the World (The Adventure Library , No 5)
# 75408 The 5 Minute Investor
# 75466 Kenai River (River Journal Series, No 5)
# 75588 Corps 05
# 75902 52 Network Marketing Tips
# 75919 Frida Kahlo 1907-1954
# 76007 25 Thunderous Classics
# 76210 California Coastal Access Guide (5th ed)
# 76234 365 Saints
# 76387 The Canadian Frontier, 1534-1760 (Histories of the American Frontier (Paperback))
# 76437 ExamWise For Exam 1D0-425 CIW E-Commerce Designer Certification (With Online Exam)
# 76501 Principles of Macroeconomics (5th Edition)
# 76553 The Best 50 Martinis (Best 50)
# 76557 The Sting of the Scorpion (Hardy Boys Mystery Stories ; 58)
# 76641 52 Great Cheap Dates (52 Deck Series)
# 76645 Cinnamon Bear (5 cassettes)
# 76754 Real Ibiza V.5
# 77236 Mix-Up Vol.5
# 77238 The World of Muslim Women in Colonial Bengal, 1876-1939 (Social, Economic, and Political Studies of the Middle East and Asia, Vol 55)
# 77252 Best 25 Screen Hits
# 77345 45 RPM
# 77386 50 in 50
# 77466 The Declaration of Independence and Other Great Documents of American History, 1775-1865 (Dover Thrift Editions) (Dover Thrift Editions)
# 77470 Review Text in Spanish Two Years (Item # 12-5833)
# 77718 156 Strings
# 77749 Lone Wolf and Cub 5
# 77750 CCNP Support Study Guide Exam 640-506 (With CD-ROM)
# 77830 The 15-Minute Single Gourmet
# 77843 American Education, 1945-2000
# 77865 Cold Case (Tom Clancy's Net Force; Young Adults, No. 15)
# 78022 Luftwaffe Colours, 1935-1945
# 78092 Mutation (Remnants, 5)
# 78104 Thoroughbred #54
# 78121 Ford Contour & Mercury Mystique 1995 thru 2000 Haynes Repair Manual
# 78271 Great Racing Movies (The Fast and the Furious-1954/The Big Wheel/Hot Rod Girl) - EP Mode
# 78280 15 Exitos
# 78523 25 Mountain Bike Tours in Massachusetts
# 78535 Roaring Glory Warbirds, Vol. 5
# 78598 Enthusiasm and Enlightenment in Europe, 1650-1850
# 79012 Sun Records 50th Anniversary Collection
# 79024 52 Ways to Nurture Your Creativity (52 Decks)
# 79363 The Sudan Campaigns 1881-1898 (Men at Arms, 59)
# 79380 365 Bedtime Stories
# 79437 50 Fantastic Poems With Wonderful Word Prompts (Grades 4-8)
# 79491 Best Of...1958-1980
# 79509 325 Creative Prompts for Personal Journals (Grades 4-8)
# 79562 Lost Universe - Union of Evil (Vol 5)
# 79568 Lost Universe, Vol. 5
# 79636 A.D. 1250
# 79657 Programacion Con C++ Builder 5 - Con CD ROM
# 79844 1950 Jamboree
# 79917 Punk-O-Rama, Vol. 5
# 80005 Star Trek - The Next Generation, Episode 151
# 80166 50 Plus!
# 80176 Independence and Democracy in Burma, 1945-1952
# 80451 Islamic Art and Architecture, 650-1250
# 80458 Adobe Acrobat 5
# 80567 Triumph Tr2, Tr3, Tr3a 1952-62 Owners Workshop Manual (Autobooks)
# 80593 Dear Donna, It's Only 45 Hours from Bien Hoa
# 80608 Calle 54
# 80700 The Official 1995 NBA Championship
# 80703 75,000+ Baby Names for the 21st Century
# 80749 Star Trek - Voyager, Episode 25
# 80793 May 25, 2002 George, WA
# 81072 Adventures In Odyssey Cassettes #35
# 81079 The Crippled Lamb 5th Anniversary Edition
# 81175 Japanese Imperialism 1894-1945 (Clarendon Paperbacks)
# 81179 Symphonies 2 & 5
# 81236 Pacific War, 1931-1945
# 81389 Art on the Jesuit Missions in Asia and Latin America, 1542-1773
# 81467 The William Lowell Putnam Mathematical Competition 1985-2000
# 81625 The 25 Sales Secrets of Highly Successful Salespeople
# 81632 504 Absolutely Essential Words
# 81647 365 Ways to Raise Great Kids
# 82018 The Art and Architecture of Islam, 1250-1800 (The Yale University Press Pelican Histor)
# 82029 Sailor Moon, Vol. 5
# 82138 GM-Grand AmAchievaCalaisSkylarkSomerset 1985-98
# 82218 A Christmas Carol (50th Anniversary Edition)
# 82223 A Christmas Carol (50th Anniversary Edition)
# 82239 Glamorous Movie Stars of the 1950s Paper Dolls
# 82479 Babylon 5 - Learning Curve / Strange Relations
# 82560 Buck Rogers in the 25th Century
# 82603 Girl, A Guy And A Lullaby (Silhouette Romance, No. 1549)
# 82764 Fortran 95
# 82770 24-7-365
# 82787 Pokemon Johto Journeys - Team Green (Vol. 45)
# 82875 50 Ways to Relieve Heartburn, Reflux and Ulcers
# 82939 Peterson's Guide to Distance Learning Programs 2001 (Peterson's Guide to Distance Learning Programs, 5th ed)
# 82991 Scarlet Vows (Moriah's Landing) (Harlequin Intrigue Series, No. 658)
# 83018 The Making of the Arab-Israeli Conflict, 1947-1951
# 83047 Maria Callas - The 1958 Los Angeles Concert / Puccini, Rossini, et al
# 83155 Star Trek - The Original Series, Vol. 26, Episodes 51 & 52
# 83417 Diana Ross Presents the Jackson 5/ABC [Bonus Tracks]
# 83463 50 Earmarks of Apostolic Church
# 83490 Transformation (Replica 15)
# 83532 Literacy Leadership for Grades 5-12
# 83543 The 365 Most Important Events of the 20th Century
# 83646 Gate Keepers - To the Rescue (Vol. 5)
# 83677 Late Roman Cavalryman 236-565 Ad
# 83781 Chinese Collaboration With Japan, 1932-1945
# 83946 Random House Webster's Unabridged Dictionary (Version 3.0 for Windows 95/98/NT & Version 2.2 for Windows 3.1)
# 83987 Thoroughbred #53
# 84007 The Essential Conan, Volume #1 (Conan the Barbarian #1-25)
# 84052 Math Puzzlers (Grades 2-5)
# 84129 The Math-Science Adventure Series (Grade 5-8)
# 84137 Fushigi Yugi - The Mysterious Play - The Dying Land (Vol. 5)
# 84217 Learn FileMaker Pro 5.5 (With CD-ROM)
# 84537 China and the Vietnam Wars, 1950-1975 (The New Cold War History)
# 84545 Beethoven Symphonies Nos. 1-5 Transcribed for Solo Piano
# 84612 The Complete Idiot's Guide to Creating a Web Page (5th Edition)
# 84627 50 Creative Training Closers
# 84641 Mambo 5
# 84651 Mathematic Plus/Practice Workbook/Grade 5
# 84675 Thoroughbred #59
# 84691 American Impressionism and Realism The Painting of Modern Life, 1885-1915
# 84727 Live Phish Vol. 15
# 84777 Ready-To-Use American History Activities for Grades 5-12
# 84843 Everything Is Everything [CD5/Cassette Single]
# 84981 Wesley Snipes Collection (Demolition Man/Passenger 57/Murder at 1600)
# 85103 A Shocker on Shock Street (Goosebumps, No 35)
# 85112 Little House on the Prairie (5 pack)
# 85119 The Lucy Show - 5 Pack
# 85357 500 Years of European Choral Music
# 85360 Strip - 1.5 Kilometres of Urban Housing in The Hague
# 85405 Techniques of Burglar Alarm Bypassing (52050)
# 85497 The B-52's
# 85667 365 Bible Prayers for Children
# 85697 The 150 Best Slow Cooker Recipes
# 85698 Top Tunes Karaoke CDG Brooks & Dunn Artist Vol. 7 TT-057
# 85717 Top Tunes Karaoke CDG Pop Vol. 16 TT-054
# 85722 Love and a .45
# 85738 Top Tunes Karaoke Woman Pop Vol. 25 TT-108
# 85860 50 Ways to Use Your Noodle
# 85894 Collecting the 50s and 60s
# 85900 Rock Jaw Master of the Eastern Border (Bone, Book 5)
# 85915 The 15 Commandments For Peak Performance In Sales
# 85928 Mastering The AR-15
# 85967 15 Minutes
# 86035 Nothing Really Matters [US CD5/Cassette Single]
# 86054 Our Best Baby Afghans (Leisure Arts Leaflet, 2853)
# 86214 Microsoft Works 4.5 for Windows for Dummies
# 86349 Incident at Arbuk (Star Trek Voyager, No 5)
# 86359 Salamandastron (Redwall, Book 5)
# 86436 Wellington's Belgian Allies 1815 (Men-at-Arms Series)
# 86479 Internet Explorer 5 for Windows for Dummies
# 86531 Bsk #35
# 86621 Lacanian Ink 5
# 86787 The Roar Of The Greasepaint - The Smell Of The Crowd (1965 Original Broadway Cast)
# 86822 Facilitation Skills for Team Leaders (50 Minute)
# 86898 Essential Jaguar Xk Xk120/140/150
# 86928 Bosch Fuel Inject Hp1365
# 86976 1939-1950 3
# 86978 Rehearsal in Dallas 1957
# 87005 The Janissaries (Elite, No 58)
# 87067 15 Grandes Exitos
# 87225 52 Weeks of Conscious Contact
# 87548 550 Authentic Rococo Designs and Motifs for Artists and Craftspeople (Dover Pictorial Archive Series)
# 87567 After Modern Art, 1945-2000 (Oxford History of Art)
# 87688 How To... Write a Book in 53 Days
# 87712 Mixed Live Club Ra, Las Vegas (Includes Bonus DVD in 5.1 Surround Sound)
# 87746 Twin Peaks - Episodes 15-19
# 87802 Caught Live + 5
# 87830 The Greek Tycoon's Bride  (Greek Tycoons) (Harlequin Presents, 2255)
# 87896 Raks Sharki 5
# 88013 Diet Analysis Plus (CD-ROM for Windows, Version 5.0)
# 88023 Ford Windstar, 1995-98 (Chilton's Total Car Care Repair Manual)
# 88046 Dave Barry Turns 50
# 88183 Honda Cb750 Sohc Fours
# 88269 The Official U.S. Mint 50 State Quarters
# 88428 Mastering Delphi 5
# 88429 Pocahontas, 1595-1617 (Blue Earth Books
# 88490 Novell's CNA Study Guide for NetWare 5
# 88561 Logging Trucks 1915 Through 1970
# 88621 The Top 100 Masterpieces Of Classical Music Vol. 1-5
# 88710 501 Delicious Diabetic Recipes
# 88731 Harrison's Principles of Internal Medicine, 15/e Textbook & Self-Assessment and Board Review
# 88748 International Accounting and Multinational Enterprises, 5th Edition
# 88770 Draw 50 Athletes (Draw 50)
# 88775 Old Age Is Always 15 Years Older Than I Am
# 88871 P-51 Mustang
# 88929 50 Smart Dogs
# 89058 150 Ways to Increase Intrinsic Motivation in the Classroom
# 89138 The Best of Sister Sledge (1973-1985)
# 89144 Paganism and Christianity, 100-425 C.E.
# 89146 African American Women in the Struggle for the Vote, 1850-1920 (Blacks in the Diaspora)
# 89293 New York's 50 Best Skyscrapers
# 89323 Insiders' Guide to Cincinnati, 5th
# 89548 Easy Lotus Notes R5
# 89598 Television's Greatest Hits, Vol.5
# 89634 50 Gershwin Classics
# 89636 The Best 50 Focaccia Recipes (Best 50)
# 89769 5 Minute Veterinary Consult
# 89840 Dinosaur Rap (Rock 'n Learn Series) ((Rock N' Learn Series , Rl959))
# 89897 Homemade Treats for Happy, Healthy Dogs (Storey Country Wisdom Bulletin, a-258)
# 89915 Bilingual Baby, JAPANESE, Vol 5
# 89917 Almanac of the 50 States
# 90066 Pjotr Leschenko 1935
# 90117 The 85 Ways to Tie a Tie
# 90135 A Record of European Armour & Arms Through Seven Centuries (5 vol. set)
# 90138 Success to the Brave (Richard Bolitho Novels/Alexander Kent No 15)
# 90195 Lotus Notes 5.0 Quick Source Guide
# 90220 Pullman Porters and the Rise of  Protest Politics in Black America, 1925-1945 (The John Hope Franklin Series in African American History and Culture)
# 90235 Significant Others (The Tales of the City Series, V. 5)
# 90281 Massachusetts Off the Beaten Path, 5th
# 90291 1815, The Waterloo Campaign
# 90540 15 Greek Myth Mini-Books
# 90542 Bíblia de Estudio "Serie 50" -  Versión Reina Valera
# 90575 175 More Science Experiments to Amuse and Amaze Your Friends
# 90598 Microsoft BackOffice 4.5 Resource Kit
# 90696 A History of Gold and Money, 1450-1920 (Verso Modern Classics)
# 90741 Physical Acoustics, Volume 25
# 90825 Blind Pig Records' 25th Anniversary Collection
# 90830 Making Waves 50 Greatest Women In Radio And Televi
# 90858 Top Tunes M Series Karaoke Multiplex CDG  Sheryl Crow TTM-056
# 90907 A Little Night Music (1975 Original London Cast)
# 90937 4.50 From Paddington
# 91143 Elvis Presley 25th Anniversary Songbook
# 91153 Microsoft Exchange Server 5.5 Administrator's Companion
# 91204 Making Herbal Hand Creams and Salves (Storey Country Wisdom Bulletin, a-256)
# 91225 How to Improve Your Bowling by 15% to 40% in Just 21 Days
# 91254 Ellington At Newport 1956
# 91276 Steppin' Out [CD5 Single]
# 91318 Don't Stand So Close to Me [CD5 Single]
# 91320 More Than Words [CD5 Single]
# 91321 Every Breath You Take [CD5 Single]
# 91322 You Are So Beautiful [CD5 Single]
# 91336 Flash(tm) 5 Virtual Classroom
# 91364 RSW 87-95
# 91491 Jaws of Darkness (World at War, Book 5)
# 91530 The Shiggar Fraggar Show!, Vol. 5
# 91540 Chevy Small Block Factory Part & Casting Number Guide 1955-1999
# 91750 Powerbuilder 5.0
# 91758 Slade'S Secret Son (Silhouette Romance, No 1512)
# 91878 Champion Jack Dupree 1940-1950
# 91880 Emmanuelle 5
# 91888 Juan Gabriel 25 Aniversario 1971-1975, Vol. 1 [5-CD Set]
# 92008 Jours d'Image, 1977-1995
# 92039 English Pronouncing Dictionary (15th ed)
# 92241 Using Your Camera, A Basic Guide to 35mm Photography Revised and Enlarged Edition
# 92275 Women's Experience of Modernity, 1875-1945
# 92340 365 Ways to Meet People in Cleveland
# 92368 Brussels Griffon Champions 1952 to 1990
# 92376 Don't Tell Me [US CD5/Cassette]
# 92549 Director 8.5 Studio
# 92650 Practical Theology and the Ministry of the Church, 1952-1984
# 92682 Power Stone - Friends & Enemies (Vol. 5)
# 92720 Word Biblical Commentary Vol. 45, 1 & 2 Thessalonians  (bruce), 276pp
# 92797 Dragon Ball Z - Showdown (Vol. 8)(Episodes 23-25)
# 92853 Eleanor Marx, 1855-1898 (Nineteenth Century Series)
# 92903 U-Boats in Camera 1939-1945
# 92908 850 Ornamental Designs from Historic Sources (Dover Pictorial Archive Series)
# 92938 Capitalizing on Your Learning Style (Pack of 5)
# 93156 The Look-It-Up Book of the 50 States (Look-It-Up Books)
# 93568 The 356 Porsche
# 93616 Sessions at West 54th
# 93618 29/5/00 - Wembley Arena, London, England
# 93669 The Poems of Charlotte Smith (Women Writers in English 1350-1850)
# 93697 The Early Modern City, 1450-1750 (A History of Urban Society in Europe)
# 93700 25 Science Plays for Emergent Readers
# 93723 Pangai Noon Karate Vol 5 (Tsunami)
# 93798 52 Poems for Men
# 93826 The Irish Statute Staple Books, 1596-1687 (The Calendar of Ancient Records of Dublin. Supplement, 3)
# 93872 Compendium of Early Mohawk Valley Families (2 Vols.) (4558)
# 93925 Access New Orleans (5th Edition)
# 94021 Flash 5 for Dummies (With CD-ROM)
# 94023 50 Activities for Teaching Emotional Intelligence
# 94054 Mercedes Benz Production Models Book 1946-95
# 94089 Tenchi in Tokyo, Vol. 5
# 94109 Porgy And Bess (1956 Studio Cast)
# 94128 Best of Mambo No. 5
# 94143 El Cid and the Reconquista 1050-1492 (Men-At-Arms, No 200)
# 94146 Krause-Minkus Standard Catalog of U.S. Stamps 2002 (Krause-Minkus Standard Catalog of U.S. Stamps, 5th ed)
# 94158 3 Years 5 Months & 2 Days in the Life of--
# 94397 Japanese Naval Aviation Uniforms and Equipment 1937-45 (Elite, 86)
# 94429 Anthology (1958-1966)
# 94484 Theoretical Models of Human Development, Volume 1, Handbook of Child Psychology, 5th Edition
# 94519 365 Days of Spiritual Growth
# 94545 75 Picture Prompts for Young Writers (Grades 1-3)
# 94877 NetWare 5 CNE
# 94899 American Political Writing During the Founding Era, 1760-1805 (Two Volume Set)
# 94936 Warfare in Roman Europe, Ad 350-425 (Oxford Classical Monographs)
# 95019 The Nuremburg War Crimes Trial, 1945-46
# 95021 A History of the Human Community, Combined (5th Edition)
# 95044 Studying America Past and Present from 1865 to Accompany America Past and Present (America Past & Present)
# 95092 Year 501
# 95119 Radio Spectrum Management (IEE Telecommunications Series, No. 45) (Iee Telecommunications Series, 45)
# 95130 The Babylon 5
# 95138 Hitler's War in the East, 1941-1945
# 95185 Updated Software V. 2.5
# 95186 Webster Hall's Tranzworld, Vol. 5
# 95317 Dead Certain (Mcnab, Claire. Detective Inspector Carol Ashton Mystery, 5.)
# 95401 750 Engaging Illustrations for Preachers, Teachers, & Writers
# 95431 Planning Better Board Meetings (CarverGuide, Vol. 5)
# 95544 Cabo One and Two Family Dwelling Code, 1995
# 95567 Deploying Microsoft Exchange Server 5.5
# 95580 Babylon 5 Season 1, Set 3 - Starliner
# 95755 The Judy Garland Show, Vol. 05 (Shows 7 & 9)
# 95918 52 Week Baseball Training
# 96076 Fahrenheit 451 and Related Readings
# 96148 The Trivial Simpsons 2003 365-Day Block Calendar
# 96166 The Houses of Roman Italy 100 B.C.-A.D. 250
# 96226 Neuro-Psychological Outcomes Research (Applied Neuropsychology, Volume 5, Number 4, 1998)
# 96276 Wellington's Dutch Allies 1815 (Men-At-Arms (Osprey))
# 96279 50 Learning Songs Sung to Your Favorite Tunes
# 96322 Systems Analysis and Design (5th Edition)
# 96398 Scrooge (1935)
# 96496 The Robe (1953 Film)
# 96507 Cartoon & Character Toys of the 50s, 60s & 70s
# 96562 52nd Street
# 96625 SAS/STAT User's Guide, Version 8 (5 Volume Set)
# 96811 Star Trek - Voyager, Episode 15
# 96920 English Society, 1580-1680
# 96946 Live at Red Rocks 8.15.95
# 96972 U.S. Submarines Since 1945
# 96973 QuarkXPress 5 Bible (With CD-ROM)
# 97005 58. John Cassian
# 97011 Mig-25 'Foxbat' Mig-31 'Foxhound'
# 97050 Corvettes of the Royal Canadian Navy, 1939-1945
# 97133 The Many Adventures of Winnie the Pooh (25th Anniversary Edition)
# 97141 Pokemon - The Johto Journeys - Midnight Heroes (Vol. 50)
# 97147 Star Blazers - The Comet Empire - Series 2, Part I (Episodes 1-5)
# 97176 Yamaha, 650Cc Twins, 1970-1982
# 97373 Photoshop 5 Web Magic (Magic Series)
# 97384 Karl Popper - The Formative Years, 1902-1945
# 97391 Sr 150
# 97463 Over 150 Astonishing Beauty
# 97630 365 WWJD
# 97700 Protective Relaying (Power Engineering, 5)
# 97717 Pokemon - Charizard! (Vol. 15)
# 97725 Structural Analysis (5th Edition)
# 97794 Dick Tracy - 15-Episode Serial
# 97871 10/15/00 - Houston, Texas
# 97889 The Johns Hopkins Medical Guide to Health After 50
# 97945 365 Ways to Get Your Child to Sleep
# 98011 Simon & Schuster 75th Anniversary Vintage Crossword Treasury
# 98020 Language and Reading Success (From Reading Research to Practice, V. 5)
# 98150 Introduction to Nonparametric Item Response Theory, Vol. 5 (Measurement Methods for the Social Science)
# 98389 25 Management Lessons From the Customer's Side of the Counter
# 98437 East Coast Jazz/5
# 98485 Michael Bolton - Greatest Hits 1985-1995
# 98492 Moon River [1995 Sony Special Products]
# 98550 Video Game Bible, 1985-2002
# 98638 50's-Get Fit With the Hits!
# 98687 Maria Callas in Rehearsal , Dallas 1957
# 98696 The United States, From Sea to Sea, Moving Forward (Draw Write Now, Book 5)
# 98791 Unbelievably Good Deals and Great Adventures That You Absolutely Can't Get Unless You're Over 50
# 98835 Poodle collectibles of the 50's and 60's
# 98910 Lectionary Scenes 57
# 99033 IIS 5 Developer's Guide (With CD-ROM)
# 99046 Lonely Planet Mediterranean Europe (Mediterranean Europe, 5th ed)
# 99062 Programming With VisualAge for Java Version 3.5 (3rd Edition)
# 99164 The End and the Beginning (The Official Guide to the X-Files, Vol. 5)
# 99169 25 Demos
# 99387 Gasaraki - Revelations (Vol. 5)
# 99459 Using Technology in the Classroom (5th Edition)
# 99495 25 Totally Awesome & Totally Easy Bulletin Boards! (Grades 3-6)
# 99496 Greatest Hits, Vols. 1 & 2 (1973-1985) [Bonus CD-ROM Track]
# 99528 Polikarpov Fighters in Action Pt.1 (Aircraft No. 157)
# 99549 Yoga After 55
# 99556 The Four Freshmen and 5 Trombones/4 Freshmen and 5 Trumpets
# 99558 The Four Freshmen and 5 Trombones/4 Freshmen and 5 Trumpets
# 99794 The 5-Minute Veterinary Consult
# 99834 Teach Them Spanish! Grade 5
# 99874 Graded Go Problems for Beginners, 30 Kyu to 25 Kyu (Beginner & Elementary Go Bks.)
# 99952 Mastering ColdFusion 4.5
# 100007 500 Five-Ingredient Recipes (Better Homes & Gardens (Paperback))
# 100021 Nene, nena y guau 5
# 100045 Measuring Market Power (Contributions to Economic Analysis, 255)
# 100108 Neu! 75
# 100405 Live/1975-85
# 100479 The Journal of C. J. Jackson, a Dust Bowl Migrant, Oklahoma to California, 1935  (My Name Is America)
# 100525 Boeing B-47, B-52 and the Avro Vulcan (Legends of the Air Series Vol 5)
# 100618 Ca-Clipper 5.2
# 100670 Space Shuttle Decision, 1965-1972 (History of the Space Shuttle, Volume 1)
# 100736 Rock & Roll Machine [1995]
# 100755 Guilty Pleasures (Harlequin Blaze, No 59)
# 100924 Test CD 5
# 100939 Italian Intermezzo (Menus and Music) (O'Connor, Sharon, Menus and Music, V. 15.)
# 100955 Gardens and Gardening in the Chesapeake, 1700-1805
# 100999 15 Exitos Originales
# 101080 9 to 5 and Odd Jobs
# 101119 The World Since 1945
# 101173 Flash 5.0
# 101276 Fodor's Flashmaps Washington, D.C. 5th Edition
# 101299 Circuit Party, Vol. 5
# 101330 Morningstar Funds 500
# 101347 500 Popular Roses for American Gardeners
# 101381 45 Fine & Fanciful Hats to Knit
# 101481 The Collected Poems of Wendell Berry, 1957-1982
# 101532 Social Work, Social Welfare, and American Society (5th Edition)
# 101563 Cantatas 5
# 101723 Folks, He Sure Do Pull Some Bow! Vintage Fiddle Music 1927-1935
# 101876 How to Prepare For the CAT/6 5th Grade
# 102130 Chemical Sensors (Oxford Chemistry Primers, 52)
# 102181 Swordhunt (Star Trek, No 95/Rihannsu Book 3)
# 102203 Clothing & Accessories from the '40s, '50s, & '60s
# 102255 Developing Powerbuilder 5 Applications
# 102259 Take Your Kids to Europe, 5th
# 102292 The 1950s (Decades of the 20th Century)
# 102348 Savage Frontier, Vol. 1, 1835-1837
# 102379 Original 365 Cats Page-A-Day Calendar 2002
# 102611 '57, Chicago
# 102856 25 to Life
# 102895 Honda Shadow 1100Cc V-Twin 1985-1996
# 102905 Danzig Passage (The Zion Covenant, 5)
# 102917 Japanese Army Air Force Fighter Units and Their Aces, 1931-1945
# 103132 Paul Simon's Concert in the Park, August 15, 1991
# 103294 Vol. 5-Hip Hop Hits (Clean Version)
# 103336 Preliminary Analysis of the October 1 1965 Coup in Indonesia
# 103369 Us Cavalryman 1865-1890 (Warrior, No 4)
# 103463 3/5
# 103533 Once Upon A Mattress (1959 Original Broadway Cast)
# 103562 Full Steam Ahead, J.I. Case Tractors & Equipment 1842-1955
# 103564 25 MYTHS YOU'VE GOT TO AVOID--IF YOU WANT TO MANAGE YOUR MONEY RIGHT
# 103636 Trin-I-Tee 5
# 103677 House of Guilt (Missing Mystery, 25)
# 103735 Space 1999, Set 5
# 103743 Howards End (Everyman's Library Series, Vol.25)
# 103768 Oldsmobile / Cutlass / 442 / F85 / Toronado / Delta 88-98 / Hurst Parts Locating Guide
# 103788 Transylvania 6-5000
# 103802 Kids (1995 Film)
# 103828 152. The Barney Songbook (E-Z Play Today)
# 103846 Nancy Umeki Early Days 1950-54
# 103899 The 5ifth Column
# 103928 Hank the Cowdog 35
# 104044 Enemies (Carrier, 15)
# 104085 How Could You Do This to Me Mum? (Fab 5)
# 104192 250 Poesias Para Ninos
# 104433 Je T'Aime, Moi Non Plus (1975 Film)
# 104660 Storie Volume 45
# 104683 EVIL THIRST THE LAST VAMPIRE 5 (Last Vampire)
# 105020 Early Recordings 1935-1950
# 105037 Motectorum Pro Festis Totius Anni (1585)
# 105163 At the Blackhawk, Vol. 5
# 105299 Musica Mexicana, Vol. 5
# 105547 Novell's CNE® Clarke Notes¿ for NetWare® 5 Advanced Administration and Design & Implementation
# 105708 The British Origins of Nuclear Strategy, 1945-1955
# 105760 American Economic History (5th Edition)
# 106016 Grand Street 51
# 106042 The 25 Sales Habits of Highly Successful Salespeople
# 106048 Spanish Is Fun, Book A - Cuaderno de ejercicios (Workbook R 529W)
# 106049 365 Fun Facts for Catholic Kids
# 106083 The Name of this Book is Dogme95
# 106085 Word Biblical Commentary Vol. 35a, Luke 1
# 106114 Vol. 56, Thelonious Monk (Book & CD Set)
# 106166 Sophie (Rushton, Rosie. Fab 5.)
# 106258 Hoover's 500
# 106320 Time Out Barcelona 5 (Time Out Barcelona, 5th ed)
# 106374 Cultural Anthropology (5th Edition)
# 106386 25 Fun Songs For Kids - Old MacDonald Had a Farm
# 106396 50 All-Time Children's Favorites, Vol. 1
# 106433 Piano Concerto No. 1 in C, Op. 15 (2P4H)"
# 106443 C And The 8051
# 106477 Clymer Bmw K-Series 1985-1995
# 106574 A Porsche 356 Close-up (inspection video)
# 106579 Call Me Madam (1995 Broadway Concert Cast)
# 106739 5 Ingredient 15 Minute Cookbook
# 106771 Special Edition Using Lotus Notes and Domino R5
# 106773 Girl in the Box (Books of Magic, Vol. 5)
# 106835 The Poser 5 Handbook (Graphics Series) (Graphics Series)
# 106852 Swimming Past 50 (Ageless Athlete Series)
# 106871 Instructional Fluid Dynamics Experiments, 1993. (Fed Ser.; Vol.152)
# 106910 The New Starlight Express Vocal Selections/00312500
# 106973 California Real Estate Principles, 5E (California Real Estate Principles)
# 107151 Buck Rogers in the 25th Century
# 107208 365 Outdoor Activities You Can Do With Your Child
# 107248 Civil War on the Western Border, 1854-1865
# 107328 The Politics of Congressional Elections (5th Edition)
# 107343 March of the Pigs [5 Tracks]
# 107353 Lonely Planet Tahiti & French Polynesia (Tahiti and French Polynesia, 5th ed)
# 107443 25 Emergent Reader Mini-Books (Grades K-1)
# 107589 Map Guide to American Migration Routes, 1735-1815
# 107692 IEEE Standard Letter Symbols for Quantities Used in Electrical Science and Electrical Engineering (Std 280-1985)
# 107757 Top Pop Singles 1955-1999 (Top Pop Singles)
# 107889 2500 Keywords to Get You Hired
# 107979 Mandie Books Mystery/Adventure for Pre-Teen Readers (Boxed Set of 5 Volumes 6-10)
# 107996 The Case of the Saddle House Robbery (Hank the Cowdog, 35)
# 108018 HLM 5
# 108040 Fodor's Exploring Italy, 5th Edition (Fodor's Exploring Italy)
# 108066 Lee Canter's Assertive Discipline Elementary Workbook, Grades K-5
# 108070 Glenn Gould Collection, Vol. 5
# 108136 The Project 50 (Reinventing Work)
# 108194 Star Trek - The Original Series, Vol. 13, Episodes 25 & 26
# 108216 Jump5
# 108238 Pearl Harbor - December 7, 1941 (Commemorative Edition 5-Pack)
# 108297 415 Original Designs for Stained Glass (Dover Pictorial Archive Series)
# 108305 500 Nations
# 108407 Barreto 50th Anniversary
# 108542 CCNA 2.0 Prep Kit 640-507 Routing and Switching (Exam Guide)
# 108557 Love Hina (Book 5)
# 108613 Marvel Masterworks Presents The Fantastic Four, Nos. 51-60
# 108636 Songs of Robert Schumann, Vol. 5
# 108645 25 Mini-Lessons for Teaching Writing (Grades 3-6)
# 108773 Take 5
# 108964 Rarum, Vol. 5
# 108983 The Revival of 1857-58
# 109041 OMC Cobra Stern Drives, 1985-95
# 109044 Better Math in 5 Minutes a Day
# 109123 Suzuki Gsx-R750
# 109243 Star Trek - The Next Generation, Episode 153
# 109267 500 Treasured Country Recipes from Martha Storey and Friends
# 109316 90125
# 109317 J.K. Lasser's Strategic Investing After 50
# 109356 Bsk #45
# 109444 Where Do We Go from Here? (Fab 5, No 3)
# 109456 Student Solutions Manual to Accompany Physics, 5th Edition
# 109472 The Boy Friend (1954 Original Broadway Cast)
# 109573 Urban Planning Theory since 1945
# 109588 The Haunted School (Goosebumps, No. 59)
# 109601 Love Hina - Summer by the Sea (Vol. 5)
# 109747 The Making of the Habsburg Monarchy, 1550-1700
# 109786 Special Edition Using Macromedia Flash 5 (with CD-ROM)
# 110075 Psalms 73-150 (The Tyndale Old Testament Commentary Series)
# 110119 Teach Yourself VISUALLY Acrobat 5 PDF
# 110451 Double Play at Short (Classics Series , No 52)
# 110553 Better Homes and Gardens 501 Quilt Blocks
# 110575 Whitefeather'S Woman (Harlequin Historical Series, No. 581)
# 110595 World Network Vol. 45
# 110633 Fun-Filled 5- to 10-Minute Social Studies Activities for Young Learners (Grades PreK-1)
# 110799 The Best 50 Flavored Oils and Vinegars (Best 50)
# 110812 Portable Personal Possessions (Artifacts of the Spanish Colonies of Florida and the Caribbean, 1500-1800 - Volume 2)
# 110880 England Under the Norman and Angevin Kings, 1075-1225 (New Oxford History of England)
# 110892 Flash 5 Weekend Crash Course
# 110927 GTO #5
# 111001 Principles and Practice of Infectious Diseases, 5th ed. on CD-ROM
# 111120 52 Fun Party Activities for Grown-Ups (52 Decks)
# 111128 The Classic Recordings 1956-59
# 111129 Man in Black 1951-58
# 111192 StormWatch Vol. 5
# 111202 Automobile Ads of the 50's and 60's
# 111218 My Projects [CD5/12"]
# 111295 Suzuki Gs650 1981-1983
# 111363 5 Women of the English Reformation
# 111371 Selected Fiction and Drama of Eliza Haywood (Women Writers in English, 1350-1850)
# 111413 Trademarks of the 40's and 50's
# 111461 15 Days of Prayer With Saint Therese of Lisieux (15 Days of Prayer Books)
# 111531 50 Hikes in Central Pennsylvania
# 111653 Goosebumps Boxed Set, Books 57 - 60
# 111667 258 Great Dates While You Wait
# 111686 Instrument Commercial Manual (updated ed)/JS314520
# 111827 Top Tunes Karaoke CDG 60's Vol. 4 TT-154
# 112054 The Rawson Family. A Revised Memoir Of Edward Rawson, Secretary Of The Colony Of Massachusetts Bay, From 1650 To 1686; With Genealogical Notices Of His Descendants, Including Nine Generations
# 112102 Officer And A Princess (Royally Wed) (Silhouette Romance, No 1522)
# 112364 Thru the Bible 1-5 (5 Volume Set)
# 112402 The City of Dreadful Night (Canongate Classics, No 53)
# 112635 Huntington's Disease (Oxford Monographs on Medical Genetics, 45)
# 112647 Charles I 1625-1640 (Seminar Studies in History)
# 112720 Dragon Ball Z - The Saiyan Conflict (Boxed Set I - Episodes 1-25)
# 112722 Dragon Ball Z - The Namek Saga (Boxed Set II - Episodes 26-53)
# 112821 Are You Being Served Vol 5
# 112826 750 French Verbs and Their Uses
# 112843 The Literature of Travel in the Japanese Rediscovery of China 1862-1945
# 112973 15 Kilates Musicales
# 113045 Evinrude Johnson Outboard Shop Manual 1.5 to 125 Hp 1956-1970
# 113046 Finding & Buying Your Place in Country, 5E (Finding and Buying Your Place in the Country)
# 113140 500 palabras nuevas para ti / 500 Words To Grow On
# 113155 Circus Days, Vol. 4-5
# 113264 The Zine Yearbook Volume 5
# 113266 Reading and Learning to Read (5th Edition)
# 113358 French Scenic Wallpaper 1795-1865
# 113362 The 5 Essentials in Every Powerful Painting
# 113374 The Jews of Modern Britain, 1656 to 2000 (Jewish Communities in the Modern World)
# 113379 More Music From Braveheart (1995 Film)
# 113397 Volkswagen Quantum Official Factory Repair Manual 1982, 1983, 1984, 1985, 1986
# 113418 Draw 50 Cars, Trucks and Motocycles (Draw 50)
# 113437 Dancing the Data (Lesley College Series in Arts and Education, V. 5)
# 113439 500 Vital Points to Ensure Foolproof Contingency & Business Resumption Plans (Enterprise Protection, Control, Audit, Security, Risk Management and Business Continuity)
# 113501 The Humanistic Tradition, Book 5
# 113512 Michelin Morocco Map No. 959 (Michelin Maps & Atlases)
# ...
# 380189 Novell's Cne Clarke Notes for Netware 5 Networking Technologies and Service & Support
# 380321 The World to Come (Great Awakening Writings (1725-1760))
# 380415 Bmw 5-Series Service Manual
# 380456 Red Shoe Diaries 5 Weekend Pass
# 380530 Nazism and German Society, 1933-1945 (Rewriting Histories)
# 380586 Bihag Kamboji Malkosh Calcutta 1955
# 380595 Blockade Runner (Morris, Gilbert. Bonnets and Bugles Series, 5.)
# 380627 Chambre 1050
# 380676 War in Japan 1467-1615 (Essential Histories)
# 380769 Area 51 (Area 51, Book 1)
# 380908 Trio '65
# 380919 Verve Jazz Masters 15
# 380977 Warfare at Sea, 1500-1650
# 380993 Michelin Africa Northeast & Arabia Map No. 954 (Michelin Maps & Atlases)
# 380995 Life-Saving Skills Manual for Midwives (5 Volume Set)
# 381055 Fortran 90/95 for Scientists and Engineers
# 381142 The Ladies' Self Instructor in Millinery & Mantua Making, Embroidery & Applique (1853
# 381165 Garrick Ohlsson - The Complete Chopin Piano Works Vol. 5 ~ Polonaises & Impromptus
# 381200 The Best of John Fahey 1959-1977
# 381225 Seeing in the Dark, No. 35
# 381412 Chevrolet S10, S15, Sonoma, and Pick-ups, 1982-93 (Chilton's Total Car Care Repair Manual)
# 381463 Penguin Atlas of Modern History (To 1815)
# 381478 Draw 50 Monsters (Draw 50)
# 381503 Classics of Children's Literature (5th Edition)
# 381578 The 5'11" Record
# 381584 Best of Carnival in Rio [1995]
# 381659 Geo Storm and Spectrum, 1985-93 (Chilton's Total Car Care Repair Manual)
# 381805 Lee Krasner (Modern Masters Series, Vol. 15)
# 381807 The British Empire 1558-1995 (Short Oxford History of the Modern World)
# 381818 Thunder Mountain Snowmobile With 3.50 Disk For Windows
# 381920 50 Christmas Carols for All Harps
# 381922 500 Great Heartwarming Expressions For Scrapbooking & Cards (Heartwarming Expressions)
# 382014 Giant of Southern Soul 65-75
# 382157 Roots of Greek Music, Vol. 5
# 382183 Getting Started With Microsoft Visual C++ 5.0
# 382186 2.5
# 382203 Electrical Engineering Reference Manual for the Pe Exam (Electrical Engineering Reference Manual for the Pe Exam, 5th Rev ed)
# 382212 Spelling and Writing Grade 5/Basic Skills Workbook With Answer Key (Brighter Child Series)
# 382340 Hardest Hits, Vol. 5
# 382369 Haldane's Best Employment Websites for Professionals (Haldane's Best Series, 5)
# 382381 Bee Smart Baby, Vocabulary Builder 5 an educational video for infants & toddlers.
# 382387 Los Secretos de Windows 98 en Español / Spanish ¿ 150 Trucos y Guía de Referencia
# 382394 Michelangelo 1475-1564 (Basic Art)
# 382416 Fiend Without a Face/Orson Welles' Ghost Story (1958)
# 382446 Grand Street 52
# 382453 The  Top 500 Poems
# 382494 52 Fun Things to Do at the Beach (52 Deck Series)
# 382703 Cloze In On Language, Grades 3-5 (World Teachers Press reproducibles)
# 382722 Drill for Skill (Item #539P)
# 382728 Athenian Politics C. 800-500 B.C.
# 382942 Sherman Medium Tank 1942-1945 (New Vanguard, No 3)
# 382962 The Initiation of Pb500
# 383001 Reckless 1979-1995
# 383087 Team Rocket Blasts Off! (Pokemon Chapter Books #5)
# 383235 Eadweard Muybridge (55 (Series).)
# 383463 Lyrics, 1962-1985
# 383531 Advanced Lasso Professional 5
# 383547 Vault.com Guide to the Top 50 Law Firms, 3rd Edition
# 383682 America's First Battles, 1776-1965
# 383780 The 25 Most Common Sales Mistakes
# 383877 50 Ways to Save Our Children
# 383923 McDonnell Douglas F-15 Eagle (Aerofax series)
# 383971 Architecture in Italy 1500-1600 (The Yale University Press Pelican Histor)
# 384009 12 X 5
# 384059 Wade Whimsical Collectables (5th Edition) - The Charlton Standard Catalogue
# 384214 The 50 Greatest Love Songs
# 384215 Love Comes Softly (Books 5-8  Love Comes Softly Series)
# 384416 The Mercedes-Benz Since 1945
# 384479 An International System for Human Cytogenetic Nomenclature (1995)
# 384491 5 Pillars of the Visual Workplace
# 384493 The 5,000 Fingers of Dr. T
# 384500 Simon & Schuster Handbook for Writers, 5th Edition
# 384526 50 Dinnertime Classics
# 384528 50 Weekend Classics
# 384538 Population 1975
# 384570 The Praetorian Guard (Elite, No 50)
# 384586 Grayson's Surrender  (Wingman Warriors) (Silhouette Intimate Moments, No. 1175)
# 384629 501 Spanish Verbs
# 384633 Edith Piaf Song Collection (Product No. 50481348)
# 384712 Word Biblical Commentary Vol. 26, Jeremiah 1-25  (craigie/kelley/drinkard), 438pp
# 384743 Shelby Cobra/the Shelby American Original Color Archives 1962-1965
# 384863 How to Use Lotus Notes 5
# 384912 Japanese Prints During the Allied Occupation 1945-1952
# 385004 Jewish Year 2001-2002 / 5761-5762 Wall Calendar
# 385023 The Art of Silk Painting (Artist's Library series #35)
# 385040 25 Great Grammar Poems with Activities (Grades 3-6)
# 385176 Birth Control Politics in the United States, 1916-1945
# 385225 Later Medieval Philosophy (1150-1350
# 385276 Expectant Princess (Royally Wed) (Silhoette Romance, No 1504)
# 385283 Top Tunes Karaoke CDG Motown Fun Pack TT-FP35&36
# 385323 Parkett #59
# 385530 The Concise Roget's International Thesaurus (5th Edition)
# 385573 305 Authentic Art Nouveau Jewelry Designs
# 385605 A Short History of the Universe (Scientific American Library Paperback, No. 53.)
# 385619 Michelin Provence/Cote d'Azur, France Map No. 245 (Michelin Maps & Atlases)
# 385631 The Sandman Vol. 5
# 385694 America's Public Holidays, 1865-1920
# 385711 Jukebox Hits of the '50s [Collectables]
# 385768 Safe Operation of Vacuum Trucks in Petroleum Service, Publ 2219/852-22190
# 385835 Thank You in Advance [CD5/Cassette]
# 385928 Shocking Request (Silhouette Romance, No. 1573)
# 385960 The Classic 1000 Seafood Recipes (Classic 1000, 15)
# 386013 Junctional Complexes of Epithelial Cells -No. 125 (CIBA Foundation Symposia Series)
# 386037 50 Years of Arrl
# 386049 Structured Clinical Interview for DSM-IV Axis I Disorders (SCID-I), Clinician Version (Set of Administration Booklet and Packet of 5 Score Sheets)
# 386077 50 States (Fandex Family Field Guides)
# 386119 The Fabulous 50's [3-CD Set]
# 386146 Embedded Design with the PIC18F452
# 386513 Zen Buddhist Landscape Arts of Early Muromachi Japan (1336-1573) (S U N Y Series in Buddhist Studies)
# 386686 Aircraft Technical Dictionary (3rd ed - JS312625)
# 386734 Late Marque Spitfire Aces 1942-45 (Osprey Aircraft of the Aces, 5)
# 386769 Gene Pitney - 25 All-Time Greatest Hits
# 386773 365 Meditations, Refelctions & Restoratives For Women Who Do Too Much Page-A-Day Calendar 2002
# 386804 Animorphs #35
# 386909 Arming the Suckers 1861-1865
# 387190 Great Voices of the '50s Vol. 3--Robin, Patzak, Gueden
# 387284 To the Top! Climbing the World's Highest Mountain (Step-Into-Reading, Step 5)
# 387340 Marcus Aurelius (Loeb Classical Library 58)
# 387437 Oklahoma [CD5/Cassette]
# 387484 German Army 1933-1945
# 387488 6502 (65XX)
# 387693 ColdFusion 5.0 Certified Developer Study Guide
# 387796 52 Ways To Have Fun, Fantastic Sex - A Guidebook For Married Couples
# 387807 MCSE Exchange Server 5.5 Exam Cram (Exam
# 387855 July 5, 2002 Morrison, CO
# 388052 Parasyte #5
# 388383 Leadership in Organizations (5th Edition)
# 388590 China's Universities, 1895-1995
# 388705 Fm8501
# 388724 Proactive Police Management (5th Edition)
# 388813 Treat Her Right (Men To The Rescue) (Harlequin Temptation, No. 852)
# 388818 North American T-28 Trojan (Naval Fighters Series No 5)
# 388987 35 Rubrics & Checklists to Assess Reading and Writing (Grades K-2)
# 388993 High-Rate Reactive Magnetron Sputter Deposition and Characterization of Metal Oxide Films (Comprehensive Summaries of Uppsala Dissertations, 520)
# 389339 Fundamentals of Physics, 5E, Extended, Textbook, Study Guide and Student Solutions Manual
# 389490 15 Big Ones/Love You
# 389611 Mechanics of Materials (5th Edition)
# 389880 Lotus WordPro 96 for Windows 95 - Illustrated
# 389980 Macromedia ColdFusion 5 Training from the Source (With CD-ROM)
# 389990 The Emergence of Whitehead's Metaphysics 1925-1929 (Suny Series in American Social History)
# 390130 The Dell Book of Logic Problems, Number 5 (Dell Book of Logic Problems)
# 390215 Wild Irish Rogue (Zebra Bouquet 53)
# 390220 PDF with Acrobat 5
# 390488 Teaching in the Outdoors (5th Edition)
# 390539 50 Legendary Stars of Sports
# 390591 The Case of the Missing Cat (Hank the Cowdog, 15)
# 390624 Control Freak (Sweet Valley High Senior Year No. 35)
# 390888 For Sale by Owner in California (For Sale By Owner in California, 5th ed)
# 390900 Grand Ole Opry 75th Anniversary, Vol. 2
# 390927 El Mejor Novio Del Mundo (Lagalera Popular, 53)
# 391036 The Vicar of Dibley, Vol. 5 - Autumn & Winter
# 391161 Creatures of Rokugan - An L5R Rpg D20 Supplement
# 391208 Typographics 5
# 391251 Essentials of Fire Department Customer Service (35918)
# 391309 New York Times Daily Crossword Puzzles, Volume 55 (New York Times Daily Crossword Puzzles)
# 391418 Oxycise! Level Two - 15 Minute Workout and Body Positions Demonstration
# 391494 Las Siete Partidas, 5 vol. set (The Middle Ages Series)
# 391501 Buck Rogers in the 25th Century
# 391752 Building WebObjects 5 Applications
# 391798 Know Your .45 Auto Models 1911 & A1
# 391818 30 Days to Understanding the Bible in 15 Minutes a Day
# 391861 Real World Adobe Indesign 1.5
# 391924 The Shelters of Stone (Earth's Children Series, No 5)
# 391969 Red Thunder Reckoning (Flesh and Blood) (Harlequin Intrigue Series, No. 657)
# 392026 Revolutionary Girl Utena - Darkness Beckoning (Vol. 5)
# 392284 Symphonies 2 & 15
# 392297 50 Best Short Hikes in California Deserts (Hiking & Biking)
# 392388 The Edge of the World (The Keepers of the Maser, 5)
# 392435 Directories for the City of Charleston, South Carolina, for the Years 1849, 1852, and 1855
# 392464 50 Ways to Close a Sale
# 392794 Avengers '68 Set 5
# 392977 Age of Gunpowder Empires, 1450-1800 (Essays on Global and Comparative History)
# 393046 Future Sounds of Jazz, Vol. 5 [Compost]
# 393123 Ernest L. Boyer, Selected Speeches, 1979-1995
# 393142 Monty Python's Flying Circus - Set 5 (Epi. 27-32)
# 393163 Holder and Fastie Alphabet Chart 25-Pack, Contains 25 8 1/2 x 11 Cards
# 393205 Elizabeth's Broken Arm (Sweet Valley Kids, No. 35)
# 393226 501 Sewing Hints
# 393269 52 Simple Ways to Manage Your Money
# 393296 VOLVO-PENTA SSTERN DR VIL III1992-1995
# 393323 New York's 50 Best Places to Find Peace and Quiet (New York's 50 Best Series)
# 393688 Illuminations (New Directions Paperbook, No. 56)
# 393708 A Political History of Western Europe Since 1945 (5th Edition)
# 393711 Nmr Imaging of Materials (Monographs on the Physics and Chemistry of Materials, 57)
# 393872 KJV Cameo Reference Edition Red Letter with Concordance and Dictionary Burgundy calfskin RCD257
# 393876 U.S. Army 1941-45 (Men at Arms Series, 70)
# 393958 50 Hikes in Central Florida
# 393968 Kelly's Heroes (1970 Film) / The Cincinnati Kid (1965 Film)
# 394086 In Search of Lost Time Volume VThe Captive & The Fugitive (In Search of Lost Time , Vol 5)
# 394179 1950s TV's Greatest Westerns
# 394271 Foods That Made Wisconsin Famous 150 Great Recipes
# 394377 50 Questions on the Natural Law
# 394409 Michelin Poland Map No. 974, 5e
# 394444 The Rough Guide to Tunisia (Tunisia (Rough Guides), 5th ed)
# 394457 I Wanna Be That Girl [CD5/Cassette]
# 394742 The Story of O - Vol. 5 / Episodes 9 and 10
# 394890 An Introduction to Hybrid Dynamical Systems (Lecture Notes in Control and Information Sciences, 251)
# 395045 California Real Estate Law, 5E
# 395047 Jean-Yves Thibaudet ~ Mendelssohn - Piano Concerto No. 1 & 2 · Variations sérieuses, op. 54 · Rondo capriccioso, op. 14
# 395102 A Report of a Murder (Dedalus Europe 1995)
# 395180 Life at the Texas State Lunatic Asylum, 1857-1997 (Centennial Series of the Association of Former Students, Texas a & M University)
# 395197 Pokemon - Johto League Champions - Fire and Ice (Vol. 54)
# 395200 Victory in the Pacific 1945 (History of United States Naval Operations in World War II, Vol.14)
# 395315 Treatise on Divine Predestination (Notre Dame Texts in Medieval Culture, V. 5)
# 395336 Best Resumes for $75,000 + Executive Jobs, 2nd Edition
# 395386 Fahrenheit 451 (Novel Units)
# 395545 1975
# 395792 50 Years of the Gibson Les Paul
# 395840 Trucker's Jukebox, Vol. 5 [Universal]
# 395848 Distracted [CD5/Cassette]
# 395864 Complete Masterworks Recordings, Vol. 5
# 395923 Spotnicks Vol. 2 + 15
# 395955 Anthology (1965-1972)
# 396034 The Wedding Wager (Harlequin Historical Series, No. 563)
# 396129 The Fifth-Century Chroniclers. Prosper, Hydatius and the Gallic Chronicle of 452 (ARCA, Classical and Medieval Texts, Papers and Monographs 27) (Arca, 27)
# 396172 8051 Microcontroller and Embedded Systems, The
# 396306 Poland's Navy, 1918-1945
# 396440 1500 Fuentes para la PC en CD-ROM, las mejores True Type Fonts
# 396786 S'Wonderful 1949-50 Recordings
# 396808 Garfield Tooth Fairy (Garfield Games & Sticker Fun, #5)
# 396862 Roaring Through the Century, The Indianapolis 500
# 396960 5 Steps to a 5 on the Advanced Placement Examinations
# 397074 50 Trail Runs in Southern California
# 397400 Churchill at War 1940-1945
# 397406 When Time Began (Book V) (The Earth Chronicles, Book 5)
# 397451 Columbia/Epic Singles 1969-75
# 397542 King Camp Gillette 1855-1932
# 397806 Beverly Kills 50187
# 397873 Michelin Map No. 573 Northern Spain, 2001 Edition
# 397880 25 Terrific Literature Activities for Readers of All Learning Styles (Grades 4-8)
# 397942 Mannlicher Model 95 Rifle and Carbine
# 397970 Agincourt 1415 (Campaign ; No. 9)
# 398033 Now, Vol. 52 [UK]
# 398091 Honeymooners Vol. 5
# 398152 Sixty Studies for the Violin, Op. 45
# 398334 Project QuarkXPress 5
# 398500 Morningstar Mutual Fund 500
# 398542 Jacob Riis (55)
# 398565 Spelling Workout, Grade 5 (Student Edition)
# 398585 Lonely Planet Vietnam (5th ed)
# 398590 365 Manners Kids Should Know
# 398612 The Best of Backyard Wrestling, Vol. 5
# 398695 Screen World 1999, Vol. 50 (Screen World)
# 398718 The Best 50 Omelets (Best 50)
# 398745 500 Cross-Stitch Blocks
# 398784 1985-2001
# 398837 1950's Birdland Broadcasts
# 398978 History of United States Naval Operations in World War II 15 Volume Set
# 399046 MCAD/MCSD Training Guide (70-315)
# 399084 Winter Soldier (Soldiers Of Fortune) (Silhouette Desire, No 1351)
# 399100 Pony to the Rescue (Pony Pals No. 5)
# 399238 Collected Poems of Dylan Thomas 1934-1952 (New Directions Book)
# 399286 Live Bird '65-'67
# 399320 Mastering ColdFusion 4.5
# 399371 Advanced Macromedia ColdFusion 5 Application Development (2nd Edition)
# 399584 Pronunciation in American English, V.5.0
# 399647 Chevy 55-56-57 (Enthusiast Color Series)
# 399776 Arms and Armor in Colonial America, 1526-1783
# 399800 35 Up
# 399814 Age of Charlemagne (Men at Arms, 150)
# 400211 A History of Sparta, 950-192 B.C.
# 400602 Lawman's Redemption  (Heartbreak Canyon) (Silhouette Intimate Moments, No. 1159)
# 400769 25 Favorite Italian Love Songs
# 400794 Eagles - Their Greatest Hits 1971-1975
# 400797 Their Greatest Hits (1971-1975)
# 401017 KJV Cameo Wide Margin Reference Bible Black Calfskin Leather KWMC257
# 401025 25 Stupid Mistakes Dog Owners Make
# 401033 Mambo No. 5/Tricky Tricky
# 401111 Original 365 Bible Verses-a-Year Page-A-Day Calendar 2003
# 401153 1949-1950
# 401239 Halloween 5 - The Revenge of Michael Myers (Widescreen Edition)
# 401520 50th Anniversary Annual Report on the Work of the Organization
# 401633 The Lexicon-Encyclopedia Interface (Current Research in the Semantics/Pragmatics Interface, V. 5)
# 401697 Insiders' Guide to Cape Cod, Nantucket and Martha's Vineyard, 5th
# 401931 50 Legendary Stars of Sports
# 402014 The American Atlas, Expanded 5th Edition
# 402016 Love Beyond Words (50th Book) (Silhoette  Special Edition, No 1382)
# 402099 Upstairs Downstairs Remembered - 25th Anniversary
# 402110 The Battleship Potemkin (1925 Film) / The Holy Mountain (1926 Film) (Score Re-recordings)
# 402124 Strategies for Teaching Students with Learning and Behavioral Problems (5th Edition)
# 402373 Ranma 1/2 Random Rhapsody - Wacky Winter Wonderland (Vol. 5)
# 402431 Avant-Garde Page Design 1900-1950
# 402485 The Jack Benny Program No. 5 (Jack is Kidnapped/The Lucille Ball Show)
# 402656 15 Easy Lessons That Build Basic Writing Skills in Grades K-2 (Scholastic Teaching Strategies)
# 402759 Fun with Bing & Louis (1949-1951)
# 402994 Sams Teach Yourself Perl 5 for Windows NT in 21 Days
# 403044 The College Board Guide to 150 Popular College Majors
# 403081 Area 51
# 403165 Joel-Peter Witkin (Phaidon 55s)
# 403305 Thatcherism and British Politics, 1975-1997
# 403345 1995 Carburizing and Nitriding With Atmospheres

# %% [markdown]
# ##### Input the product id of the product bought by user

# %%
tempinput = int(input())
if(tempinput in n):
  pro_id = tempinput
  print("Selected product is", pro_id)
else:
  print("Empty node has been removed from the graph!")
# Out:
# 65
# Selected product is 65

# %% [markdown]
# #####Final result denotes all the connected edges to the source(source is product selected)

# %%
finalresult = []
resultarray = np.unique(getclean(pro_id))
for i in range(1, len(resultarray)):
    if(resultarray[i] in n):
        finalresult.append(resultarray[i])

print(len(finalresult))
# Out:
# 9

# %% [markdown]
# #####Helper function to display titles

# %%
def showtitles(array):
    titles = []
    for i in range(len(array)):
        titles.append(G.nodes[array[i]]['title'])
    return titles

# %% [markdown]
# ##### Helper function to display ASIN numbers

# %%
def showasin(array):
    asins = []
    for i in range(len(array)):
        asins.append(G.nodes[array[i]]['ASIN'])
    asins = np.array(asins)
    #asins = asins.astype(int)
    return asins

# %%
t = showtitles(finalresult)
print(G.nodes[pro_id]['title'],"\n\n\n", t)
# Out:
# Economics for Business
#
#
#  ['Advanced Pediatric Clinical Assessment', 'A Charlie Brown Christmas', 'Houghton Mifflin Mathematics', 'Ballroom Dancing', 'Irish Stew!', 'Cpt 2003', "The O'Reilly Factor", 'The 2R Manager', 'Iyanla Live!']

# %% [markdown]
# ##### Helper Function to retrive a subset of the dictionary(i.e the features we are concerned with)

# %%
def getsubdict(d):
    required_keys = ('group' ,'num_categories', 'totalreviews', 'downloadedreviews', 'avg_rating')
    subdict = {x: d[x] for x in required_keys if x in d}
    return subdict

# %% [markdown]
# **NOTE**
#
# Here, our initial approach was to calculate Correlation and Cosine similarities between the features of the two nodes to determine the "weight", or how similar they were.
# However, that approach was erroneous. Correlation implies that a product with high salesrank will be highly correlated with a product with high salesrank. But, Low salesrank is desirable.
#
# Hence, we moved to a new metric - Jaccard Index.

# %%
# def gethighestcorr(pro_id, finalresult, metric):  
#     corrdict = {}
#     cosdict = {}   
#     selarray = np.array(list(getsubdict(G.nodes[pro_id]).values()))
#     selarray = selarray.astype(float)
#     for i in range(1,len(finalresult)):
#         comparray = np.array(list(getsubdict(G.nodes[finalresult[i]]).values()))
#         comparray = comparray.astype(float)        
#         if(pro_id != i):
#             cosineval = cosine_similarity([selarray], [comparray])[0][0]
#             cosdict[finalresult[i]] = cosineval
#             corr = np.corrcoef(selarray, comparray)[0][1]
#             corrdict[finalresult[i]] = corr               
#     corrdict = dict(sorted(corrdict.items(), key=lambda item: item[1], reverse = True))
#     cosdict = dict(sorted(cosdict.items(), key=lambda item: item[1], reverse = True))
#     print(corrdict, cosdict)
#     if(metric == 'corr'):
#       return corrdict
#     elif(metric == 'cosine'):
#       return cosdict
# metric = input()
# finaldict = gethighestcorr(pro_id, finalresult, metric)
# len(finaldict)
# top5 = np.array(list(finaldict.keys()))[:5]
# top5
# showtitles(top5)
# showasin(top5)
# arr1 = np.append(top5, pro_id)
# finalresult = np.array(finalresult)
# diff = np.setdiff1d(finalresult, top5)
# arr2 = np.append(diff,pro_id)
# H = G.subgraph(arr1)
# L = G.subgraph(arr2)
# fig = plt.figure(1, figsize=(20, 10), dpi= 200)
# nx.draw_networkx(H, with_labels = True, edge_color = 'r')
# nx.draw_networkx(L, with_labels = True)
# print(pro_id)
# print(finalresult)
# print(top5)
# type(top5)
#Saving the graph locally to implement efficiently in API
#nx.write_gpickle(G,'drive/MyDrive/BAJAJ/GNN_datasets/G.gpickle')

# %% [markdown]
# #### **Jaccard index is a metric that is a a function of number of nodes, not node attributes. Hence, it serves out purpose.**
#
# The Jaccard Index, also known as the Jaccard similarity coefficient, is a statistic used in understanding the similarities between sample sets. The measurement emphasizes similarity between finite sample sets, and is formally defined as the size of the intersection divided by the size of the union of the sample sets. The mathematical representation of the index is written as:
#
# ![image.png](data:image/png;base64,...)

# %%
def jaccard_similarity(list1, list2):
    intersection = len(list(set(list1).intersection(list2)))
    union = (len(set(list1)) + len(set(list2))) - intersection
    return float(intersection) / union

# %% [markdown]
# #####Helper function to calculate jaccard index values

# %%
def gethighestjaccard(pro_id, finalresult):
  jaccdict = {}    
  for i in range(0,len(finalresult)):     
    if(pro_id != i):      
      tempneighbours = []
      resarray = getclean(finalresult[i])        
      jaccdict[finalresult[i]] = jaccard_similarity(finalresult, resarray)
  return jaccdict

# %% [markdown]
# Sorting the Final Dictionary based on Jaccard Indexes

# %%
finaldictjaccard = gethighestjaccard(pro_id, finalresult)
finaldictjaccard = dict(sorted(finaldictjaccard.items(), key=lambda item: item[1], reverse = True))

# %%
finaldictjaccard
# Out:
# {29: 0.05555555555555555,
#  64: 0.0,
#  126: 0.46153846153846156,
#  127: 0.46153846153846156,
#  128: 0.35714285714285715,
#  129: 0.35714285714285715,
#  130: 0.26666666666666666,
#  131: 0.05555555555555555,
#  132: 0.46153846153846156}

# %%
top5jac = np.array(list(finaldictjaccard.keys()))[:5]

# %%
top5jac
# Out:
# array([126, 127, 132, 128, 129])

# %% [markdown]
# #### Top 5 Recommendations Made

# %%
showtitles(top5jac)
# Out:
# ['Houghton Mifflin Mathematics',
#  'Ballroom Dancing',
#  'Iyanla Live!',
#  'Irish Stew!',
#  'Cpt 2003']

# %% [markdown]
# #### Assigning red edges for recommended products, and blue edges for non-recommended products

# %%
K = nx.DiGraph()
for i in top5jac:
  K.add_edge(pro_id,i,color='r')
difjac = np.setdiff1d(finalresult, top5jac)
for i in difjac:
  K.add_edge(pro_id,i,color='b')

# %%
fig = plt.figure(1, figsize=(5, 3), dpi= 200)
colors = nx.get_edge_attributes(K,'color').values()
nx.draw_networkx(K,with_labels = True, edge_color=colors)
